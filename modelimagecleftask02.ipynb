# %%
import os
import librosa
import numpy as np

# Step 1: Specify the folder path containing the audio files
folder_path = "extracted_content/clips"

# Step 2: List all the files in the folder
file_list = os.listdir(folder_path)

# Step 3: Filter only the .wav files
wav_files = [file for file in file_list if file.endswith(".wav")]

# Step 4: Define the desired length for padding
max_length = 200  # Adjust this value based on your requirements

# Step 5: Loop through each .wav file
for wav_file in wav_files:
    # Step 6: Load the audio file
    audio_path = os.path.join(folder_path, wav_file)
    audio_data, sample_rate = librosa.load(audio_path, sr=None)

    # Step 7: Process the audio file as needed
    # For example, converting the audio to spectrograms
    spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate, n_fft=128)

    # Step 8: Pad or truncate the spectrogram to the desired length
    if spectrogram.shape[1] < max_length:
        # Pad the spectrogram if its length is less than the desired length
        padding = max_length - spectrogram.shape[1]
        spectrogram = np.pad(spectrogram, ((0, 0), (0, padding)), mode='constant')
    elif spectrogram.shape[1] > max_length:
        # Truncate the spectrogram if its length is greater than the desired length
        spectrogram = spectrogram[:, :max_length]
# Out:
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)

# %%
import os
import librosa
import numpy as np
import json
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Input, Dense, Attention, Reshape
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
import json

# Load train.json
with open('train.json', 'r') as f:
    train_data = json.load(f)

# Load valid.json
with open('valid.json', 'r') as f:
    valid_data = json.load(f)

# Preprocess audio data for training and validation
# This includes loading audio files, preprocessing them, and tokenizing target sequences
# Define function to preprocess audio data
def preprocess_audio(audio_path, target_shape,n_fft=1024):
    audio_data, sample_rate = librosa.load(audio_path, sr=None)
    spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
    if spectrogram.shape[1] < target_shape[1]:
        padding = target_shape[1] - spectrogram.shape[1]
        spectrogram = np.pad(spectrogram, ((0, 0), (0, padding)), mode='constant')
    elif spectrogram.shape[1] > target_shape[1]:
        spectrogram = spectrogram[:, :target_shape[1]]
    spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
    spectrogram -= np.mean(spectrogram)
    spectrogram /= np.std(spectrogram)
    return spectrogram

# Preprocess audio data for training and validation
target_shape = (128, 200)  # Example shape, adjust as needed

# Extract audio paths and target sequences from the data
train_audio_paths = [os.path.join('extracted_content/clips', entry['src']) for entry in train_data]
valid_audio_paths = [os.path.join('extracted_content/clips', entry['src']) for entry in valid_data]

X_train = [preprocess_audio(audio_path, target_shape) for audio_path in train_audio_paths]
X_valid = [preprocess_audio(audio_path, target_shape) for audio_path in valid_audio_paths]

train_target_sequences = [entry['tgt'] for entry in train_data]
valid_target_sequences = [entry['tgt'] for entry in valid_data]
# Out:
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=160
#   warnings.warn(
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=159
#   warnings.warn(
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1281
#   warnings.warn(
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1760
#   warnings.warn(
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1920
#   warnings.warn(
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1440
#   warnings.warn(

# %%
# Define the maximum vocabulary size
max_vocab_size = 30000

# Initialize a tokenizer
tokenizer = Tokenizer(num_words=max_vocab_size, oov_token="<OOV>")

# Fit the tokenizer on the target sequences
tokenizer.fit_on_texts(train_target_sequences)

# Convert text to sequences of numerical indices
train_sequences = tokenizer.texts_to_sequences(train_target_sequences)
valid_sequences = tokenizer.texts_to_sequences(valid_target_sequences)

# Pad sequences to ensure uniform length
#max_sequence_length = max(len(seq) for seq in train_sequences + valid_sequences)
train_sequences_padded = pad_sequences(train_sequences, maxlen=200, padding='post')
valid_sequences_padded = pad_sequences(valid_sequences, maxlen=200, padding='post')

# %%
train_sequences_padded[0].shape
# Out:
# (200,)

# %%
# Define the input shape
input_shape = (128, 200)  # Example shape, adjust as needed

# Define the encoder input
encoder_input = Input(shape=input_shape, name="encoder_input")

# Define the decoder input
decoder_input = Input(shape=input_shape, name="decoder_input")

# Define the encoder LSTM
encoder_lstm = LSTM(256, return_sequences=True, return_state=True, name="encoder_lstm")
encoder_outputs, state_h, state_c = encoder_lstm(encoder_input)
encoder_states = [state_h, state_c]

# Define the decoder LSTM
decoder_lstm = LSTM(256, return_sequences=True, return_state=True, name="decoder_lstm")
decoder_outputs, _, _ = decoder_lstm(decoder_input, initial_state=encoder_states)

# Define the attention mechanism
attention_layer = Attention()
attention_output = attention_layer([encoder_outputs, decoder_outputs])

# Define a dense layer to map the attention output to the desired features
dense_layer = Dense(200, activation="relu", name="dense")
mapped_attention_output = dense_layer(attention_output)

# Reshape the mapped attention output to match the input shape
reshaped_attention_output = Reshape((128, 200))(mapped_attention_output)

# %%
# Define the model
model = tf.keras.Model([encoder_input, decoder_input], reshaped_attention_output)

# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error",metrics = ['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 128, 200)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_lstm (LSTM) │ [(None, 128,      │    467,968 │ encoder_input[0]… │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256), (None,      │            │                   │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_input       │ (None, 128, 200)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_lstm (LSTM) │ [(None, 128,      │    467,968 │ decoder_input[0]… │
# │                     │ 256), (None,      │            │ encoder_lstm[0][… │
# │                     │ 256), (None,      │            │ encoder_lstm[0][… │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention           │ (None, 128, 256)  │          0 │ encoder_lstm[0][… │
# │ (Attention)         │                   │            │ decoder_lstm[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128, 200)  │     51,400 │ attention[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 128, 200)  │          0 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 987,336 (3.77 MB)
#  Trainable params: 987,336 (3.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define batch size and custom number of epochs
batch_size = 128
num_epochs = 10

def data_generator(X, batch_size):
    for i in range(0, len(X), batch_size):
        encoder_input_batch = X[i:i+batch_size]
        decoder_input_batch = X[i:i+batch_size]  # Same as encoder input for autoencoder
        target_batch = X[i:i+batch_size]  # Same as input for autoencoder
        yield ((encoder_input_batch, decoder_input_batch), target_batch)

# Create data generators
train_generator = tf.data.Dataset.from_generator(
    lambda: data_generator(X_train, batch_size),
    output_signature=(
        ((tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32), 
          tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32)), 
         tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32))
    )
).repeat()

valid_generator = tf.data.Dataset.from_generator(
    lambda: data_generator(X_valid, batch_size),
    output_signature=(
        ((tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32), 
          tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32)), 
         tf.TensorSpec(shape=(None, 128, 200), dtype=tf.float32))
    )
).repeat()

# %%
# Training
model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // batch_size,
    epochs=num_epochs,
    validation_data=(valid_generator),
    validation_steps=len(X_valid) // batch_size
)
# Out:
# Epoch 1/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1412s 7s/step - accuracy: 0.0242 - loss: 0.5341 - val_accuracy: 0.0541 - val_loss: 0.3837
# Epoch 2/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1419s 8s/step - accuracy: 0.0561 - loss: 0.3769 - val_accuracy: 0.0810 - val_loss: 0.3628
# Epoch 3/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1444s 8s/step - accuracy: 0.0814 - loss: 0.3643 - val_accuracy: 0.0966 - val_loss: 0.3591
# Epoch 4/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1440s 8s/step - accuracy: 0.1014 - loss: 0.3568 - val_accuracy: 0.1646 - val_loss: 0.3355
# Epoch 5/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1435s 8s/step - accuracy: 0.1902 - loss: 0.3348 - val_accuracy: 0.2845 - val_loss: 0.3173
# Epoch 6/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1430s 8s/step - accuracy: 0.2957 - loss: 0.3204 - val_accuracy: 0.3638 - val_loss: 0.3164
# Epoch 7/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1417s 7s/step - accuracy: 0.3748 - loss: 0.3138 - val_accuracy: 0.4374 - val_loss: 0.3119
# Epoch 8/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1409s 7s/step - accuracy: 0.4534 - loss: 0.3108 - val_accuracy: 0.5068 - val_loss: 0.3106
# Epoch 9/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1413s 7s/step - accuracy: 0.5245 - loss: 0.3082 - val_accuracy: 0.5715 - val_loss: 0.3043
# Epoch 10/10
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1409s 7s/step - accuracy: 0.5769 - loss: 0.3050 - val_accuracy: 0.6046 - val_loss: 0.3039

# %%
# Load test.json
with open('test.json', 'r') as f:
    test_data = json.load(f)

# Preprocess audio data for test samples
X_test_encoder = []  # For encoder input
X_test_decoder = []  # For decoder input
id = []  # To store test sample IDs

for sample in test_data:
    audio_path = os.path.join('extracted_content/clips', sample['src'])
    spectrogram = preprocess_audio(audio_path, (128, 200))  # Assuming spectrogram shape is (128, 200)
    if spectrogram is not None:
        X_test_encoder.append(spectrogram)
        X_test_decoder.append(spectrogram)  # Decoder input same as encoder input
        id.append(sample['id'])

# Convert test data to NumPy arrays
X_test_encoder_numpy = np.array(X_test_encoder)
X_test_decoder_numpy = np.array(X_test_decoder)

# %%
# Preprocess audio data for test samples
X_test = []
test_ids = []  # To store test sample IDs
for sample in test_data:
    audio_path = os.path.join('extracted_content/clips', sample['src'])
    spectrogram = preprocess_audio(audio_path, (128, 200))  # Assuming spectrogram shape is (128, 200)
    if spectrogram is not None:
        X_test.append(spectrogram)
        test_ids.append(sample['id'])

# Convert test data to TensorFlow dataset
test_dataset = tf.data.Dataset.from_tensor_slices(X_test)

# %%
# Make predictions on test data
predictions = model.predict([X_test_encoder_numpy, X_test_decoder_numpy])
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step

# %%
# Define a reverse mapping from indices to words or pictogram terms
reverse_word_index = {index: word for word, index in tokenizer.word_index.items()}

# Decode token indices into words or pictogram terms
hyp = []
for prediction in predictions:
    decoded_prediction = []
    prev_word = None
    for index in np.argmax(prediction, axis=-1):
        word = reverse_word_index.get(index, '')
        # Check if the current word is different from the previous one
        if word != prev_word:
            decoded_prediction.append(word)
            prev_word = word
    # Filter out empty strings and join the words/pictogram terms into a single string
    decoded_prediction_str = ' '.join(filter(None, decoded_prediction))
    # Capitalize the first letter of each word
    decoded_prediction_str = ' '.join(word.capitalize() for word in decoded_prediction_str.split())
    hyp.append(decoded_prediction_str)

# %%
# Print the first ID and its corresponding decoded prediction
print("ID:", id[0])
print("Decoded Prediction:", hyp[0])
# Out:
# ID: cefc-tcof-Acc_del_07-17
# Decoded Prediction: Haut Rã©flã©chir Avoir Un Corps Truc Passã© Et Nous Rã©flã©chir Passã© Mettre Il Nous Rã©flã©chir Mettre Et Aprã¨s Savoir Rã©flã©chir Aprã¨s Savoir Au Faire Savoir Et Au Aprã¨s Savoir Et Trop Faire Savoir Avoir Et Faire Savoir Au Faire Au Tu Haut Rã©flã©chir Aprã¨s Rã©flã©chir Tu Rã©flã©chir Haut Rã©flã©chir Haut Savoir Haut Rã©flã©chir Vois Rã©flã©chir Truc Rã©flã©chir Vois Rã©flã©chir Heureusement Vois Le Vois Le Rã©flã©chir Savoir

# %%
print(predictions[0])
# Out:
# [[0.2195904  0.46313396 0.8887986  ... 0.         0.         0.        ]
#  [0.21325555 0.5549171  0.95220447 ... 0.         0.         0.        ]
#  [0.47446433 0.8124995  1.0803368  ... 0.         0.         0.        ]
#  ...
#  [0.13632785 0.37387532 0.5607461  ... 0.         0.         0.        ]
#  [0.0520239  0.33662152 0.51994246 ... 0.         0.         0.        ]
#  [0.         0.2733747  0.4927201  ... 0.         0.         0.        ]]

# %%
import json
import zipfile
import os

# Load test.json to get the IDs
with open('test.json', 'r') as f:
    test_data = json.load(f)

# Write the predictions and corresponding IDs to run.json
with open('run.json', 'w') as run_file:
    for idx, prediction in enumerate(hyp):
        # Get the corresponding ID from test.json
        sample_id = test_data[idx]['id']
        # Write to run.json
        json_line = {'id': sample_id, 'hyp': prediction}
        run_file.write(json.dumps(json_line) + '\n')

# Zip the run.json file
with zipfile.ZipFile('run.zip', 'w') as zipf:
    zipf.write('run.json', os.path.basename('run.json'))

# %%
import json
import zipfile
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score



# Prepare data for run.json
run_data = []

for idx, (id, hyp) in enumerate(zip(id, hyp_valid)):
    print("id:", id)
    print("hyp:", hyp)
    
    # Append ID and Decoded Prediction to run_data
    run_data.append({"id": id, "hyp": hyp})

# Write run_data to run.json
with open("run.json", "w") as json_file:
    json.dump(run_data, json_file)

# Create run.zip containing run.json
with zipfile.ZipFile("run.zip", "w") as zip_file:
    zip_file.write("run.json")

print("run.json and run.zip created successfully.")
# Out:
# id: cefc-tcof-Acc_del_07-19
# hyp: <oov> <oov> Ã©poque Parler Ils <oov> Le Maison Groupe Groupe But But Maison Lã Groupe Ils Maison Maison Me Oui Passã© 00 00 Un Un Passã© Maison 00 00 00 Oui Maison Maison Une Ãªtre Maison Maison Maison 00 00 00 Maison 00 00 00 00 Maison Maison Maison Maison Maison Me 00 Maison Me Me Maison Maison Maison Oui Maison Oui Oui Oui Oui Oui Oui Maison Alors Alors Oui Alors Alors Oui Oui Oui Que <oov> <oov> <oov> Que Ã©poque Ã©poque <oov> Alors Alors Alors Ã©poque Ã©poque Est <oov> <oov> <oov> Ã©poque <oov> <oov> <oov> <oov> <oov> <oov> <oov> Est Est <oov> <oov> <oov> <oov> Ã©poque <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> Il Il <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov>
# id: cefc-tcof-Acc_del_07-28
# hyp: Les Les Celui Celui Alors Que Lã Le Passã© Ils Avoir Que Que Toi Le Le Il Nous Non Oui Oui Oui Un Un Ã Ã Alors Lã Lã Le Le Que Que Lã Lã Le Le Le Le Le Lã Lã Lã Lã Lã Lã Lã Lã Lã Lã Oui Oui Un Un Que Oui Oui Un Oui Oui Alors Alors Oui Il Alors Toi Alors Alors Alors Alors Le Lã Lã Alors Alors Oui Un Un Celui Me Me Celle Celle Oui Celle Me Me Les Les Les Les Les Les Les Les Les Les Les Les Les Les Les Les Celle Me Me Me Les Me Me Me Me A A A A Les Les Les Les A Les Les A Les Les Les Les
# id: cefc-tcof-Acc_del_07-54
# hyp: Nous Nous Il Il Exact Passã© Que Que Un Oui Alors A A Lã Lã Le Le Un Rã©flã©chir Passã© Ils Devoir Pour Un Ils Ils Ils Ils Plus Avec Ils Ils Aller Ils Plus Ils Devoir Devoir Plusieurs Plusieurs Plusieurs Un Un Quoi Exact Plus Un Un Ils Ils Vous Faire Faire Faire Ils Ils Ils Ils Ils Ils Ils Ils Rã©flã©chir Il Les Les Lã Nous Les Les Nous Nous Il Ils Ils Les Ils Pour Pour Nous Nous Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Nous Nous Il Nous Nous Il Il Du Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il
# id: cefc-tcof-Acc_del_07-8
# hyp: Faire Instant Instant Trop Gens Maintenant Donner Donner Travailler Instant Par Haut Rã©flã©chir Est Maintenant Maintenant Venir Instant Instant Rã©flã©chir Est Est Partir Place Ce Ce Instant Pour Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Instant Leur Instant Instant Leur Leur Instant Instant Leur Leur Leur Leur Instant Leur Leur Instant Instant Leur Avant Avant D'accord D'accord D'accord Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Faire Faire Rã©flã©chir Rã©flã©chir Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Avant Avant Faire Avec Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Faire Trois Trois Trois Trois Faire Faire Faire Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois
# id: cefc-tcof-Acc_kom_07-147
# hyp: Passã© Passã© Passã© Passã© Passã© Alors Celui Passã© Passã© Le Le Au Celle Celui Celui Passã© Non Non Ils Ils Non Non Passã© Passã© Ils Ils Non Non Non Passã© Non Ã Ã Non Non Passã© Celui Celui Non Non Non Non Non Passã© Passã© Passã© Ãªtre Ãªtre Ãªtre Ãªtre Passã© De Le Le Le Passã© Passã© Parce Parce Parce Passã© Pour Ils Ils Quand Dire Ils Ils Passã© De Quand Passã© Passã© Passã© De De Ils Parce Parce Quand Non Passã© Le Le Le Le Le Le Le Le Le Non Non Non Quand Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le Le
# id: cefc-tcof-Acc_kom_07-34
# hyp: Autre Vouloir Vouloir Vouloir Alors Trouver Grand Personne Donner Dire Alors Trouver Grand Arrive Trois Trois Partir Autre Autre Son Ton Ton Seconde Seconde Parler Instant Non Non Autre Ou Truc Seconde Seconde Non Non Non Autre Autre Ou Ou Seconde Non Non Non Non Non Non Parler Seconde Autre Autre Autre Seconde Seconde Seconde Seconde Beaucoup Beaucoup Non Seconde Seconde Beaucoup Beaucoup Beaucoup Beaucoup Son Son Son Son Son Son Son Son Son Son Son Seconde Beaucoup Au Beaucoup Beaucoup Autre Non Non Une Parce Dire Personne Trop Trop Ce Ce Trop Instant Dire Minimum Ce Ce Personne Trois Trois Trois Parce Y Y Pour Minimum Minimum Minimum Minimum Avant Avant Avant Pour Pour Pour Avant Avant Avant Cã´tã© Avoir Avoir Pour Pour Avant Leur Leur Ce
# id: cefc-tcof-Acc_kom_07-45
# hyp: Vous Vous Mon Mon Vous Quelqu'un Exact Lã Pouvoir Dans Ã Passã© Plus Pouvoir Pouvoir Fois Ã Non Pouvoir Pouvoir Pouvoir Pouvoir Prochain Passã© Parce Pouvoir Pouvoir Prochain Prochain Elle Si Pouvoir Pouvoir Pouvoir Si Si Si Si Si Pouvoir Si Si Si Si Si Si Pouvoir Pouvoir Si Si Si Pouvoir Pouvoir Pouvoir Pouvoir Quoi Pouvoir Voir Voir Pouvoir Autre Autre Pouvoir Autre Plus Pouvoir Autre Avec Le Vouloir Sur Truc Vouloir Celui Celui Celui Vouloir Celui Pouvoir Pouvoir Celui Celui Celui Truc Truc Celui Celui Celui Celui Truc Truc Truc Vous Vous Truc Truc Corps Du Corps Mon Vous Vous Devoir Devoir Devoir Devoir Mon Mon Mon Que Que Que Que Que Vous <oov> Que Que Que Vous Vous Que Vous Vous Vous Vous Vous Vous
# id: cefc-tcof-Acc_kom_07-53
# hyp: Une Tout Une Alors Oui Un Faire Comme Oui Nous Nous Comme Comme Oui Que Lã Oui Oui Oui Une Que Que Exact Celle Celle Pouvoir Oui Un Voir Celle Un Un Une Une Une Quoi Pouvoir Quoi Une Un Oui Pouvoir Alors Alors Une Une Une A Une Une Une Alors A Une Une Une Alors Une Une Une Plusieurs Une Une Alors Alors Alors Alors Alors Une Une Alors Oui Celui Alors Alors Une Une Une Une Une Une A Une Une Celui Celui Celui Un Une Une Et Et Oui Une Une Une Une Une Une Une Une Une Oui Faire Une Une Une Faire Faire Faire Faire Faire Faire Faire Faire Un Une Faire Une Faire Faire Faire Tout Faire Faire Faire Faire Faire
# id: cefc-tcof-Acc_kom_07-66
# hyp: Que Si <oov> Que Et Ã Lã Si Si Vois Plus Plus De Lã Lã Aprã¨s Si Comme Dans Le Lã Vois Exact Aprã¨s Si Si Si Comme Comme Comme Vois Aprã¨s Aprã¨s Si Si Si Si Quoi Aprã¨s Aprã¨s Aprã¨s Si Comme Si Si Si Savoir Savoir Si Si Si Comme Comme Dans Aprã¨s Comme Comme Comme Dans Aprã¨s Que Comme Si Que Que Aller Lã Lã Lã Lã Nous Ã Lã Lã Passã© Vois Aprã¨s Lã Dans Passã© Celui Lã Lã Lã Lã Que <oov> Heureusement Vois Lã Que Que Lã Lã Aller Que Que Que Que Si Si Vois Mon Mon Vois Aprã¨s <oov> <oov> <oov> Si <oov> Que Quoi Que <oov> <oov> <oov> Que Que Lã Lã Lã Lã Que Lã Lã Lã Si
# id: cefc-tcof-Ag_ael_08-13
# hyp: Avoir Ãªtre Passã© Une Pour Haut Dans Si Plus Lã Que Tout Dire Elle Prochain Le Lã Lã Lã Lã Passã© Quand Avoir Avoir Le Ville Sur Vouloir Autre Celui Celui Avoir Avoir Un Quelqu'un Le Le Lã Celui Celui Avoir Avoir Le Le Ville Celui Celui Celui Lã Le Me Ville Celui Celui Vouloir Autre Autre Passã© Celui Celui Sur Le Passã© Passã© Passã© Lã Lã Passã© Lã Que Passã© <oov> Que Que Que <oov> Haut Que Que Haut Celui Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Haut Savoir Aprã¨s Savoir Savoir Savoir Savoir Savoir Savoir Aprã¨s Aprã¨s Savoir Savoir Savoir Savoir Savoir Savoir Aprã¨s Aprã¨s Haut Aprã¨s Savoir Savoir Savoir Savoir Savoir Savoir Que Lã Lã Tu
# id: cefc-tcof-Ag_ael_08-168
# hyp: Corps Expliquer Autre Dur Se Dur Commencer Le <oov> Autres Oã¹ Chaque Partir Non Enfants Par Dur Mã©tier Ã§a Enfants Minimum Vous Vous Savoir Heureusement Plus Avec Du Aprã¨s Tu Tu Plus Plus Dur D'accord D'accord Chaque Plus Dur Dur Dur Savoir Tu D'accord D'accord D'accord Dur Tu Tu Parler Minimum Aprã¨s Autres Rã©flã©chir Aprã¨s Aprã¨s Mon Ensemble Rã©flã©chir Avec Avec Autre Autre Vous Quelqu'un Par Nous Sur Ville Ville Ville Ville Quelqu'un Quelqu'un Quelqu'un Ou Autre Nous Nous Aprã¨s Rã©flã©chir Ville Aprã¨s Aprã¨s Du Truc Truc Eux Sur Ville Ville Avec Avec Avec Plus Souvent Autre Autre Autre Eux Retourner Mois Retourner Retourner Arrive Mois Mois Retourner Retourner Retourner Retourner Mois Mois Mois Mois Retourner Retourner Retourner Retourner Mois Mois Mois Mois Mois Mois Mois Mois Mois
# id: cefc-tcof-Ag_ael_08-179
# hyp: Celui Association Dans Mettre Association Plus Annã©e Vouloir Heureusement Association Par Parce Il Elle Elle Annã©e Association Vous Devoir Comme Avec Annã©e Annã©e Annã©e Me Quelqu'un Quelqu'un Annã©e Annã©e Annã©e Lã Quelqu'un Quelqu'un Avec Ou Ou Lã Que Quelqu'un Comme Par Sur Le Sur Quelqu'un Par Quelqu'un Truc De De Quelqu'un Avec Avec Annã©e Annã©e Annã©e Annã©e Annã©e Me Annã©e Rã©flã©chir Pouvoir Quoi Haut Haut Et Quoi Rã©flã©chir Ã Toi Il Nous Il Il Il Plus Plus Voir Voir Voir Et Il Nous Il Plus Plus Plus Plus Et Et Et <oov> <oov> Aller Trop Prendre Prendre Trop Trop Trop Trop Trop Trop Trop Trop Trop Trop Trop Prendre Trop Trop Il Il Trop Trop Trop Trop Trop Trop Trop Trop Trop Trop Mettre Trop Trop Trop Trop
# id: cefc-tcof-Ag_ael_08-184
# hyp: Passer Passer Prendre Parler Son Il Gens Maintenant Se Se Ville Rã©flã©chir Rã©flã©chir Gens Maintenant Son Toi Pouvoir Nous Celui Celui Beaucoup Le Mon Mon Beaucoup Mãªme Annã©e Mon Mon Nous Beaucoup Par Prendre Prendre Nous Beaucoup Beaucoup Annã©e Annã©e Annã©e Maintenant Beaucoup Nous Corps Prendre Il Il Corps Corps Mon Corps Association Corps Mon Comment Association Le Lã Mãªme Mãªme Lã Celui Les Les Rã©flã©chir Celui Comment Rã©flã©chir Rã©flã©chir Celui Celui Celui Celui Celui Celui Celui Celui Celui Me Rã©flã©chir Me Par Mãªme Avoir Ãªtre Ãªtre Me Alors Alors Alors Alors Une Une <oov> <oov> Celui Celui Me Me Me <oov> Me <oov> <oov> <oov> <oov> <oov> Que Me Me <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov>
# id: cefc-tcof-Ag_ael_08-192
# hyp: Exact D'accord Ã©pisodiquement 00 Non Ã©pisodiquement Ensemble Gens Venir Maison Expliquer Ensemble Ãªtre Quand Corps Corps Un Me Dire Et Tu Expliquer Expliquer Expliquer Rã©flã©chir Rã©flã©chir Partir Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Me Un Un Expliquer Expliquer Expliquer Expliquer Oui Savoir Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Instant Expliquer Instant Expliquer Souvent Souvent Expliquer Grand Souvent 00 Souvent Souvent Me Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Vous Expliquer Vous 00 Celui 00 00 Expliquer 00 Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer D'accord D'accord Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Enfants Enfants Expliquer Expliquer Expliquer Deux Deux Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer Expliquer
# id: cefc-tcof-Ag_ael_08-37
# hyp: Corps Lucratif Tu Haut Son Ville Plus Tout Trop Mettre Mãªme Mãªme Quelqu'un Plus Devoir Elle Lucratif Lucratif Lui Rã©flã©chir Son Mãªme Mãªme Fois Haut Haut Rã©flã©chir Rã©flã©chir Beaucoup Son Son Son Son Son Rã©flã©chir Corps Rã©flã©chir Beaucoup Son Son Son Son Son Mettre Corps Beaucoup Beaucoup Son Son Son Son Son Son Rã©flã©chir Beaucoup Beaucoup Haut Haut Haut Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Haut Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Beaucoup Rã©flã©chir Rã©flã©chir Haut Rã©flã©chir Rã©flã©chir Au Rã©flã©chir Corps Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Haut Haut Haut Haut Haut Corps Corps Corps Par Il Par Par Par Corps Par Par Corps Corps Corps Corps Corps Corps Corps
# id: cefc-tcof-Ag_ael_08-49
# hyp: Maintenant Jouer Grand But <oov> Piã¨ce Vã©ritã© But Maison Quand Que Il Instant Instant Dernier Corps Ã©pisodiquement Enfants Groupe Une Vã©ritã© Vã©ritã© Que Elle Du Vous Enfants Peu Travailler Travailler Quatre Quatre Ã©pisodiquement Ensemble Enfants Enfants Autres Sortir Sortir Inventer Inventer Inventer Sortir Sortir Sortir En Quatre Ã©pisodiquement Lã Lã Alors Alors Alors Autres Quatre Oã¹ Se Quatre Enfants Enfants Haut Du Quatre Vã©ritã© Enfants Me Bien Bien Cã´tã© Jouer Ãªtre Ãªtre Donner Donner Est Est Comme Dans Dans Dans Cã´tã© Comme Jouer Cã´tã© Cã´tã© Jouer Quatre Ton Dans Il Tout Tout Me Me Me Ãªtre Ãªtre Ãªtre Cã´tã© Oã¹ Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Cã´tã© Souvent D'accord D'accord D'accord D'accord D'accord Trouver Trouver Grand Grand Grand Grand Grand Grand Grand
# id: cefc-tcof-Ag_ael_08-67
# hyp: Non Non Dans Dire Les Dans A A Parce Fois Dans Dans Une Alors Avoir Oui Dans Dans Celle Une Une Une Avoir Celle Oui Dans Dans Alors Une Une Plusieurs Celle Oui Dans Dans Une Une Une Une Celle Celle Dans Dans Une Une Une Plusieurs Avoir Alors Une Une Une Une Celle Alors Dans Une Une Alors Alors Dans Dans Alors Alors Alors Dans Alors Alors Celle Celle Plusieurs Celle Oui Oui Une Alors Oui Une Celle Alors Une Une Celle Celle Celle Celle Celle Celle Oui Oui Oui Oui Oui Oui Oui Oui Ils Oui Oui Celle Celle Celle Celle Celle Celle Celle Celle Dans Les Non Ils Ils Ils Ils Non Dans Un Un Un Oui Un Celle Celle Dans Les Dans Dans Dans
# id: cefc-tcof-Ag_ael_08-68
# hyp: Gens Sortir Juste Inventer Comment Ã©pisodiquement Problã¨me Au Une Plusieurs Celle Autre Emploi Juste Autres Au Oui Oui A Celle Celle Beaucoup Seconde Groupe Nous Trouver Heureusement Parce Leur Leur Peu Peu Prochain D'accord Retourner Avant Avant Avant Lã Association Association Grand Trouver Vois Parce Parce De De Prochain Nous Cã´tã© Parce Ãªtre Ãªtre Prochain Prochain Prochain Avant Elle Elle Prochain Prochain Enfants Elle Elle Avant Avant Mois Mois Retourner Mois Mois Leur Ã©poque Mois Avant Avant Avant Avant Avant Avant Avant Autres Autres Enfants Seconde A Groupe Aprã¨s Commencer Avant Commencer Pendant Avant Minimum Avant Prochain Prochain Leur Monsieur Minimum Parler Ils Ils Ils Ils Commencer Commencer Ils Commencer Commencer Commencer Commencer Commencer Commencer Commencer Quand Quand Quand Et Rester Rester Rester Expliquer Expliquer Expliquer Expliquer Rester
# id: cefc-tcof-Ag_ael_08-9
# hyp: 00 Infã©rieur Alors Passer Venir Dans Prochain Parler Gros Au Journã©e Devoir Ses Ses Quand <oov> <oov> Mettre Matin Sur Venir Venir Instant Me Ses Ses Ses Gros Que Grand Grand Venir Passer Instant Acheter Infã©rieur Ses Ses Ses Grand Grand Venir Passer Commencer Instant Gens Gens <oov> Grand Grand Comment Comment Plus Plus Maintenant Pouvoir Grand Parents Amã©liorer Ton Personne Trois Grand Grand Ton Ton Quand Me Grand Me Bien Bien Arrive Arrive Son Leur Attendre Attendre Deux Avant Ton Ton Deux Ton Bien Deux Deux Leur Lui Venir Avant Venir Venir Venir Journã©e Venir Venir Venir Arrive Arrive Lui Leur Avant Avant Leur Avant Avant Arrive Arrive Personne Peu Venir Venir Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous
# id: cefc-tcof-Ago_ram_07-13
# hyp: Tout Truc Parce Truc Tout Tout <oov> Aller Quoi Quand Et <oov> Aller Un Tout Parce <oov> Pouvoir Le Le Le Le Le Le Sur Sur Ville Quelqu'un Sur Sur Sur Sur Ville Quelqu'un Sur Sur Avec Avec Quelqu'un Quelqu'un Sur Sur Sur Ville Quelqu'un Sur Sur Sur Sur Sur Sur Sur Le Le Le Le Le Le Le Le Si Si Le Le Autre Autre Si De Ou Ou Et Sur Pouvoir Le Le Le Le Le Parce Si Si Si Il Il Oui Le Le Sur Le Sur Le Le Le Pouvoir Pouvoir Si Pouvoir Pouvoir Pouvoir Le Pouvoir Pouvoir Pouvoir Pouvoir Le Quelqu'un Le Le Sur Sur Sur Le Pouvoir Pouvoir Ou Autre Autre Pouvoir Pouvoir Pouvoir Sur Sur Quelqu'un Quelqu'un Le Le Si
# id: cefc-tcof-Ago_ram_07-4
# hyp: Commencer Commencer <oov> Beaucoup Toi Oui Pour Personne Son Son Nous Et Devoir Voir Celui Lucratif Lucratif Quelqu'un Exact Un Lui Ville Avec Lã Lã Pour Ville Se Que Arrive Arrive Arrive Arrive Ils Ville Ville Avoir Lã Le Ils Deux Deux Deux Arrive Arrive Arrive Arrive Lã Se Se Arrive Ils Les Ville Que Que Les Les Lui Un Celle Lui Heureusement Un Un Heureusement Heureusement Me Exact Exact Oui Lui Parler Un Ville Que Que Celui Que Heureusement Heureusement Heureusement Par Arrive Arrive Par Par Les Arrive Heureusement Heureusement Les Lã Que Lã Oui Oui Oui Lã Avoir Me Plus Lui Celle Celle Celle Lã Lã Lã Arrive Arrive Se Lui Lui Lui Lui Lui Parler Un Les Les Arrive Arrive Arrive Arrive Lã Me Beaucoup
# id: cefc-tcof-Ago_ram_07-95
# hyp: Sur Rien Piã¨ce Aller Partir Piã¨ce Autre Comme Parce D'accord Du Sur Tout Quand Ils Travailler Cã´tã© Instant Instant Autre Aller Dans Dans Quoi Corps Comme Rã©flã©chir Haut Trop Vois Haut Elle Autre Association Elle Elle Elle Corps Retourner Retourner Mois Savoir Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Comme Elle Elle Quoi Quoi Elle Aprã¨s Dans Aprã¨s Aprã¨s Fin Dans Aprã¨s Dans Tout Tout Tout La Parce Parce Quand Quand Dans Ils Quand Quand Elle Dire Entrer Dans Dire Leur Quand Ils Ils Quand Quand Quand Dire Dire Rã©flã©chir Elle Elle Elle Travailler Travailler Travailler Travailler Dire Dire Cã´tã© Cã´tã© Cã´tã© Travailler Travailler Travailler Travailler Travailler Travailler Travailler Travailler Travailler Travailler Travailler Travailler Parce Parce Parce Parce Cã´tã© Travailler Travailler Travailler Mois Mois Travailler Travailler Travailler
# id: cefc-tcof-Alg_jac_06-15
# hyp: Ã Ã Non Non Non Voir A Avec Non <oov> Nous Voir Voir Avoir Que Nous Nous <oov> <oov> <oov> Prochain Prochain Non Non Non Nous Prochain Prochain Prochain Fois Le Non Non Ã Ã Prochain Non Non Passã© Non Non Ã Ã Ã Ã Le Il Il Nous Nous Nous Nous Nous Nous Il Nous Nous Nous Passã© Il Nous Nous Nous Prochain Avoir Avoir Passã© Passã© Celle Quand Ils Devoir Celle Non Ã Celle Avec Avec Passã© Celui Celui Nous Nous Fois Fois Fois Fois Fois Fois Fois Fois Fois Fois Fois Fois Nous Celui Ã Ã Celui Nous Alors Alors Avec Ã Me Nous Nous Nous Ã Ã Nous Ã Ã Ã Ã Fois Fois Fois Fois Ã Fois Non Non Ã Ã Ã
# id: cefc-tcof-Alg_jac_06-187
# hyp: Ils Un Que <oov> Oui Lã Que Nous Non Plusieurs Lã Que Y <oov> <oov> Un Un Celui Passã© Avoir Avoir Faire Passã© Celui Passã© Passã© <oov> Faire Faire Au Au Au Au Faire Au Au Au Au Au Au Au Passã© Passã© Un Faire Celui Passã© Un Un Passã© Passã© Passã© Passã© Celui Celui Celui Passã© Passã© Nous Ã Non Non Oui Oui Oui <oov> Alors Alors A A Y Y Y Alors Alors Alors Une Une Passã© Passã© Alors Alors Alors Passã© Passã© Passã© Passã© Passã© Passã© Passã© Celui Oui Alors Alors Alors Alors Alors Alors Alors Alors Alors Oui Oui Oui Alors Alors Oui Oui Oui Alors Alors Alors Alors Alors Alors Alors Alors Alors Non Passã© Alors Alors
# id: cefc-tcof-Alg_jac_06-230
# hyp: Autre Ou Ou Prochain Me De Le Savoir Quoi Une Passã© Celui Le Le Lã <oov> A Non Aller Elle Elle Vouloir Autre Autre Ou Truc Vous Pour Pour Avoir Avoir Savoir Savoir Aprã¨s Savoir Vous Truc Autre Autre Une Aprã¨s Avoir Avoir Vous Vous Vous Au Avoir Avoir Passã© Ou Avoir Avoir Oui Savoir Oui Avoir Avoir Passã© Autre Celle Celle Pour Vous Aprã¨s Savoir Savoir Vouloir Vouloir Il Y Celle A A Toi Et Et Toi Toi Toi A Il Toi Toi Toi <oov> Toi Toi Une Toi Toi Toi Il Toi Toi Toi Toi Toi Toi Toi Toi Toi Toi Toi Toi Il Il Toi Toi Il Toi Toi Toi Toi Toi Toi Toi Toi Toi Il Toi Toi Toi Toi Toi Toi Toi
# id: cefc-tcof-Alg_jac_06-295
# hyp: Du Du Quand Ã Passã© Passã© Vous Mãªme Tu Haut Ã Passã© Celui Pour Y Le Le Du Passã© Avoir Que Que <oov> <oov> <oov> <oov> <oov> Vois Mon Aprã¨s Mãªme Savoir Rã©flã©chir Quoi Quoi Quoi Pouvoir Pouvoir Du Du Du Rã©flã©chir Haut Pouvoir Pouvoir Pouvoir Vous Vois Heureusement Heureusement Lui Rã©flã©chir Quoi Prochain Elle Vois Heureusement Prochain Avoir Avoir Prochain Les Au Au <oov> Sur Ville Toi Celui Celui Celui Celui Celui Celui Celui Celui Toi Toi Passã© Et Toi Au Au Pouvoir Celui Toi Toi Toi Toi Toi Celui Celui Nous Me Celui Celui Celui Celui Celui Celui Toi Toi Toi Toi Celui Celui Celui Celui Celui Celui Celui Celui Celui Celui Celui Celui Toi Celui Celui Celui Celui Celui Celui Toi Toi
# id: cefc-tcof-Alg_jac_06-318
# hyp: Tout Vous Chaque Vous Vous Annã©e Vous Vous Oã¹ Vous Vous Mãªme Prendre Seconde Vous Mãªme Mãªme Mãªme Heureusement Haut Tu Vous Vous Annã©e Annã©e Heureusement Oã¹ Oã¹ Beaucoup Beaucoup Beaucoup Oã¹ Chaque Oã¹ Beaucoup Beaucoup Beaucoup Oã¹ Beaucoup Tu Tu Beaucoup Beaucoup Chaque Prendre <oov> Oã¹ Beaucoup Seconde Vous Son Chaque Chaque Beaucoup Beaucoup Chaque Chaque Chaque Beaucoup Beaucoup Beaucoup Chaque Annã©e Annã©e Oã¹ Oã¹ Du Vous Tu Tu Vous Tu Heureusement Heureusement Par Heureusement Heureusement Tu Lui Du Tu Tu Du Vous Vous Vous Vous Vous Vous Du Tu Du Heureusement Heureusement Heureusement Vous Vous Vous Tu Vous Vous Vous Vous Vous Vous Du Du Vous Vous Vous Vous Vous Vous Vous Vous Du Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir Savoir
# id: cefc-tcof-Alg_jac_06-337
# hyp: Que Que La Nous Partir <oov> <oov> Que Lui Est Ã©pisodiquement Ã©pisodiquement Lã Que Que Sur Sur Prochain Comme La Parce Notre Au Au Nous Vois Les Et Trois Association Association Ã©pisodiquement Ã©pisodiquement Ã©pisodiquement Ã©pisodiquement Ensemble Ensemble Trop Mettre Mettre Me Parce Grand Grand Grand Toi Me Ensemble Parce Parce Ã Ã Nous Toi Ensemble Trop Nous Beaucoup Toi Toi Il Trop Association Que Les Au <oov> Trop Association Au Au <oov> Prochain Sur <oov> Quoi Que Sur Que <oov> <oov> Toi Au Au Au Au Au Mettre A A Trop Au Au Au Au Au Maintenant Heureusement Maintenant Heureusement Heureusement Heureusement Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Il Il Il Il Il Il Il Toi Il Il Il
# id: cefc-tcof-Alg_jac_06-8
# hyp: A Toi Toi Le Non Non Et Toi Avoir Pour A Les Les Et Et Pour Y Celle Et Et Et Et Y Toi De Et Et Et Celle Une Celle Les Les Les Les Les Les Et Et Les Et Et Et Et Les Et Et Et Et Et Et Plusieurs Et Et Et Une Une Toi Toi Y A Non Non Y Y Non Y Toi Toi Un Un Toi Passã© Et Et Oui Et Et Les A Passã© Non Y De Lã Lã Et Et Et Et Et Une Passã© Il Non Il Nous Il Il Il Il Il Il Il Il Il Nous Nous Il Il Il Il Il Il Il Il Il Il Nous Nous Toi Il Il Il Toi Toi Toi
# id: cefc-tcof-Alise-143
# hyp: Tout Une Ã Haut Haut Quoi Celle Au Ã Que Que Non Savoir Haut Devoir Devoir Avoir Une Une Ã Non Non Savoir Savoir Devoir Quoi Celle Les Toi Il Ã Ã Tu Savoir Quoi Tu Celle Et Toi Il Il Ã Ã Aller Celle Au Et Et Toi Il Ã Aller Celle Les Et Toi Il Ã Ã Les Et Toi Toi Ã Ã Non Non Tu Y Ã Ã Une Plusieurs A Et Ã Ã Ã Ã Ã Ã Ã Non Non Une Ã Une Une Alors Non Non Non Ã Non Non Ã Ã Ã Ã Ã Ã Et Et Et Ã Ã Ã Ã Ã
# id: cefc-tcof-Alise-149
# hyp: Dire Exact Comme Si Si Exact Devoir Une Les Fois Dans Ils Ils Comme Voir Aller Passã© Les Et Quand Tout Tout Ils Voir Devoir Passã© Que <oov> Elle Dire Parce Parce Dans Quoi Celui Que Que <oov> Elle Elle Dire Parce Tout Dans Celui <oov> <oov> Et Elle Dire Dire Tout Tout Que <oov> Et Quand Dire Celui Que Que Aller Quoi Celui Un Un Un Un Passã© Que Que Un Comme Comme Lã Que <oov> Comme Que <oov> Passã© Que Que Dire Tout Les <oov> <oov> <oov> Que Parce <oov> <oov> <oov> <oov> <oov> <oov>
# id: cefc-tcof-Alise-150
# hyp: Dire Quand Ils De Tout Avec Prochain Quoi Elle Pour Pour De Tout Vouloir Quelqu'un Passã© Passã© Pour Oui De Le Quoi Vous <oov> <oov> Non Plus De De Quoi Vous Vous Avoir <oov> De De De Pour Pour Pour Pour Vous <oov> <oov> Que Pour Pour Ils De Ou Avec Le <oov> Tout De De De Comme Ãªtre Ãªtre De Elle Alors Elle Tout Dans Ãªtre De Passã© Passã© Sur Sur Quelqu'un <oov> Sur Sur Avec Sur Tout Tout Sur Sur Sur Non Ville Y Y Elle Passã© Passã© Passã© Oui Sur Celui Passã© Passã© Passã© Celui Sur Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du Du
# id: cefc-tcof-Alise-20
# hyp: Dire Voir Voir Devoir Devoir Ils Passã© <oov> Si Voir Devoir Devoir <oov> <oov> De Passã© <oov> Si Si <oov> <oov> <oov> Le Alors Lã Et Si <oov> Que <oov> De Alors Alors Et <oov> <oov> Devoir De Alors Alors <oov> Le Et Que <oov> Celle Une Une Les <oov> <oov> Non Une Et Et Ã Ã De Toi Il <oov> De Le <oov> <oov> <oov> <oov> <oov> Devoir Devoir Le <oov> <oov> <oov> Le <oov> <oov> <oov> Que <oov> Voir Devoir Lã Le Le <oov> Avoir Le Le
# id: cefc-tcof-Alise-93
# hyp: Par Donner Donner Son Donner Donner Maintenant Son Par Ton Comment Savoir Savoir Savoir Savoir Pour Y Le De Non Passã© Passer Passer Passer Donner Devoir Il Il Ã Non Passã© Passã© Commencer Voir Toi Toi Il Il Ã Non Passã© Passã© Et Et Toi Il Il Ã Toi Tu Toi Toi Toi Il Le Prochain Non Parce Toi Il Le Elle Y A Il Il Le Par Corps Passã© Il Ã Ã Toi Il Il Il Quand Quand De De Toi Le Le Non Il Passã© Passã© Ton Il Il Il Toi Passã© Le Il Passã© Passã© Passã© Passã© Il Il Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place Place
# id: cefc-tcof-Ang_jul_07-130
# hyp: Lã Lã Lã Lã Lã Lã Lã Dire Dire Dire Ãªtre <oov> Nous Il Il Il Prochain Tout Quand Avec Ils Ils Ils <oov> <oov> <oov> Lã Lã Lã Plus Exact Exact Voir Lã Lã Que Que <oov> Lã Lã Plus Exact Exact Lã Lã Lã Lã Lã Que <oov> Quoi Quoi Lã Lã Lã Que Que <oov> <oov> Aller Lã Lã Que Que Que <oov> <oov> Lã Lã Dans Tout Quand Quand Quand Exact Lã Lã Lã Exact Lã Que <oov> Plus Tout Lã Dans Dans Ils Ils Que Que Lã Lã <oov> Que Quand Quand Que <oov> Que Lã <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov>
# id: cefc-tcof-Ang_jul_07-36
# hyp: Nous Nous Fois Y Fois Fois Fois Quand Ils Dans Passã© Ã Nous Toi Toi Dire Quand Y A De Celui Lã Lã Avoir Celle Celle Les Et Et Tout Le Fois Prochain Au Au Avoir Avoir Oui Tout Tout Le Le Passã© Passã© Non Non Avoir Tout De Le Le Passã© Passã© Non Non Celui Me Me Une Lã Un Oui Alors Alors Une Une Un Un Au Au Au Au Au Au Avoir Avoir Avoir Celle Celle Celle Les Et Et Tout Tout Tout Tout Tout Parce Au Au Parce Celle Celle Et Et Et Et Et Et Et Et Oui Une Alors Une Celui Le Le Le Passã© Dans Les Celle Celle Avoir Au Avoir Celle Et Celle Les Dans Tout Le Passã© Une Alors
# id: cefc-tcof-Apprendreaulycee-13
# hyp: Parce Corps Tout 10 10 10 10 10 Lui <oov> But Rester 10 10 D'accord D'accord D'accord Exact Exact Leur Fin Rester Fois Prochain Se Son Beaucoup Voir Il De <oov> <oov> Personne Dans Prochain Vã©ritã© Travailler Rien Il Que <oov> Dernier Vã©ritã© Vã©ritã© Vã©ritã© Vã©ritã© Vã©ritã© Ã Non Que Elles Grand Dernier Personne Prochain Passã© Celui Quoi Vouloir Exact Devoir Journã©e Ãªtre <oov> Dire Se Personne Personne Que <oov> Seconde Parler But But Avant Rester A Que <oov> Rester A Jouer <oov> Rester Rester Que Dans Rester Oui But But Parler Parler Travailler Travailler <oov> But But But But Quand Quand Quand Quand Quand Quand Quand Quand Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul Seul
# id: cefc-tcof-Apprendreaulycee-148
# hyp: But Ton But Sur Quand Quand Quand Sur Quand Quand Sur Sur Quand Quand Quand Quand Oui Partir Tu Donner Celui Me Sur Sur Sur Un Un Et Donner Place Ce Tout Me Me Un Un <oov> Heureusement Oã¹ Chaque Tout Tout Me Partir Tu Heureusement Heureusement Heureusement Tout Tout Me Tu Que Vois Chaque Ce Bien Me Me Que Chaque Ce Voir Me Me Me Ce Ce Lã Me Oui Place Ce Plusieurs Me Me Ce Beaucoup Me Me Beaucoup Seconde Seconde Beaucoup Un Instant Beaucoup Un Beaucoup Beaucoup Beaucoup Beaucoup Seconde Seconde Seconde Seconde Seconde Beaucoup Beaucoup Beaucoup Beaucoup Petit Petit Petit Beaucoup Beaucoup Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux Deux
# id: cefc-tcof-Apprendreaulycee-15
# hyp: Sur Ville Sur Sur Annã©e Prendre Me Me Mon Il Faire Lucratif Celui Vois Que Me Me Ville Ville Trop Trop Annã©e But Lucratif Que Que Que Que Ils Lã Lã Avoir Au Au Passã© Comme Comme Comme Si Si Si Avoir Avoir Au Au Comme Comme Comme Si Le Avoir Plus Exact Faire Aller Aller Devoir Devoir Plus Voir Devoir Ils Le Lã Lã Prendre Ils Ils Pour Lã Vois Vois Ils Lã Lã Passã© Lui Lã Lã Vois Vois Heureusement Heureusement Heureusement Pour Pour Pour Pour Prendre Annã©e Non Rã©flã©chir Rã©flã©chir Mon Lã Lã Lã Lã Lã Lã Lã Aprã¨s Aprã¨s Aprã¨s Aprã¨s Pour Aprã¨s Aprã¨s Aprã¨s Aprã¨s Aprã¨s A A A A A A A A A A A A A Plusieurs Une Une Une
# id: cefc-tcof-Apprendreaulycee-166
# hyp: Venir Venir Y Y Y Y Y A Oui Arrive Vois Seconde Seconde Seconde Y Y Ce Commencer Oui Lã Rã©flã©chir Lui Grand Trouver Dire Seconde Et Celui Ãªtre Trop Trop Lui Heureusement Heureusement Grand Les Passã© Dire Dire Y Trop Mettre Lui Heureusement Les Nous Autre Le <oov> Dire Mettre Travailler Passer Celui D'accord D'accord Travailler D'accord Les Il Me Heureusement D'accord Avoir Les Non Ãªtre Heureusement Se Oã¹ De De Lucratif Avoir Trop Le Le <oov> Passã© De Le Oui Me De Lucratif Lucratif Beaucoup Que Beaucoup Lucratif Lucratif Lucratif Seconde Lucratif Lucratif Seconde Seconde Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif But But But But But But But But But But But But But But But But
# id: cefc-tcof-Apprendreaulycee-20
# hyp: Le Le Rã©flã©chir Arrive Passer Minimum Ã©poque Personne Arrive Commencer Non Par Par Parler Parler Est Pour Chaque Cã´tã© Instant Non Par Par Est Est Personne A Deux Ou Place Place Celle Avoir Au Parler A Petit Deux Ou Place Place Celle Celle Avoir Son Deux Deux Ou Donner Place Place Deux Deux Deux Deux Maintenant Donner Voir Le Celle Avoir Ou Ou Y A Celle Avoir Au A Plusieurs Tout Avoir Au Au Mettre Avoir Au Quoi Quoi Quoi Quoi Quoi Grand Quoi Quoi Quoi Quoi Avoir Au Quoi Quoi Quoi Quoi Quoi Quoi Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Si Si Si Si Arrive Arrive Si Si Si Quoi Comme Comme Comme Comme Quoi Quoi Quoi Quoi Pouvoir Pouvoir Il Il Il
# id: cefc-tcof-Apprendreaulycee-48
# hyp: Aprã¨s Jamais Retourner Groupe Groupe Semaine Semaine Rien Rien Jamais Jamais Cours Semaine Semaine Fin Fin Instant Instant Instant Corps Pas Semaine Semaine Semaine Celui Ãªtre Ãªtre Partir Ville Jamais Jamais Jamais Semaine Celui Fin Fin Partir Fin Jamais Jamais Jamais Jamais Fin Fin Fin Partir Autres Sur Sur Dur Jamais Fin Semaine Semaine Bien Mon Trop Trop Du Partir Semaine Aimer Trop Trop Que Du 5 5 Trop Trop Pas Pas Corps Instant Instant Pas Pas Grand Grand Grand Corps Corps Trop Grand Grand Grand Cours Du Instant Leur D'accord D'accord Avant Avant Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Leur Deux Deux Deux Deux Deux Deux Deux Arrive Arrive Arrive Arrive Arrive Arrive Arrive Arrive Arrive
# id: cefc-tcof-Apprendreaulycee-51
# hyp: <oov> Aller Une Une Une Plusieurs A Plusieurs Ãªtre Tout Celle Savoir Plusieurs A A A A Ãªtre Ãªtre Si Si Dire Celle Voir Voir Ils Ils Ils Le <oov> Quand Dire Exact Exact Voir Ils Ils Ils Ils Quand Quand Dire Dire Dire Exact Voir Ils <oov> Ils Quand Quand Tout Exact Exact Exact <oov> <oov> Quand Plus Plus Plus Que <oov> Quand Quand Quand Ils Quand Quand Quand Quand Dire Une Les Les Quand Parce Du Quand De Que Du Passã© De <oov> Au Avoir Quand Avoir Avoir Celle Celle Toi Toi Celle Les Haut Haut Haut Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Lui Lui Heureusement Lui Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Lui Lui Lui Lui Lui Lui Lui Lui Lui
# id: cefc-tcof-Apprendreaulycee-72
# hyp: Comment Problã¨me Est Tu Emploi Emploi Emploi Aimer Minimum Trop Parce Et Ou Aimer Emploi Son Si Ã©poque Est Parler Que Que Et Et Fois Dans Dans Rien Rien Parler Trouver Non Non Parce Et Dans Rien Enfants Enfants Tout Tout Tout Non Parce Enfants Enfants Rien Enfants Enfants Enfants Non Non Dire Quand Dans Alors Travailler Passã© Passã© Grand Quand Alors Parler Travailler D'accord Trouver Ãªtre Parler Seconde Seconde Trouver Grand Trop Par Si Si Si Si Exact Y Y Y Y Y Y Y Y Et Trop Voir Voir Voir Voir Vouloir Avec Avec Avec Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois Venir Venir Venir Place Place Place Place Place Place Place Place Place Place Place Place Place
# id: cefc-tcof-Apprendreaulycee-75
# hyp: Groupe Et Ensemble Et Groupe Un Rester Inventer Mon Une <oov> Place Ce Mãªme Non Rester Aimer Notre Rien Oã¹ Prochain <oov> Que Que Que Souvent Ã©pisodiquement Maison Celui Ãªtre Association Le Elle Maintenant Maintenant Que Notre Ã§a Me Se De Alors Une Comme Comme Que Ã§a Celui Quoi Se Mettre Association Elle Elle Celui Me Ãªtre Se Voir Notre Rien Me Commencer De De Le Le Que Que Que <oov> <oov> <oov> <oov> <oov> Sortir Sortir <oov> <oov> Sortir Ã©pisodiquement Notre Oui Oã¹ Oã¹ <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> Beaucoup Beaucoup Beaucoup Beaucoup <oov> Toi Toi Toi Toi Il Il Il Il Il Il Nous Nous Nous Nous Nous Nous Nous Nous
# id: cefc-tcof-Apprendreaulycee-83
# hyp: Oui Un Un Prochain Me Prochain Pouvoir Ãªtre Comme Alors <oov> Celui Celui Celui Me Me Quoi Pouvoir Prochain A Un Que Celui Celui Celui Prochain Prochain Pour Que Que <oov> <oov> Celui Celui Celui Plusieurs Que Que <oov> <oov> <oov> <oov> Celui Celui Que Que <oov> <oov> Celui Celui Prochain Quand Le Le Le Prochain Prochain Celui Me Le Prochain Celui Celui Passã© Faire Que Y Celui Celui Passã© A Une Celui Prochain Celui Oui Celui Celui Une De De Celui De Avoir Le Les Celle Les Celle Celle Celle De De De Une Au De De De De De De De Le Les Celle Celle Les Les Celle Celle Celle Les Les Celle Celle Celle Celle
# id: cefc-tcof-Apprendreaulycee-87
# hyp: Ce Tout Et Et Groupe Une Une Une Prendre Arrive Ton Avoir Au Au But Une Une D'accord Parce Lã Avec Comment Mon Ã©poque Est Au D'accord Instant A Le De Quelqu'un Vois Mon Ã©poque Prendre Prendre Instant Se Me Passer Passer Quelqu'un Prendre Prendre Prendre Prendre A Me Me Avec Quelqu'un Trop Trop Trop Du Que Avec Quelqu'un Quelqu'un A Aprã¨s Lã Que Passer Venir A Elle Celui D'accord Elle Vois Avoir Avoir Ã©poque Ã©poque Ã©poque Non Ã©poque Ã©poque Que Que Avec Quelqu'un Quelqu'un Vois Vois Heureusement Vois Mon Peu Ou Ou Elle Elle Elle Prochain Prochain Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Parler Parler Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif
# id: cefc-tcof-Aqua_05-10
# hyp: Commencer Haut Trop La Trois Ton Bien Ã©poque Travailler Ã©poque Passer Passer Petit Heure Est Instant Partir Trouver Ã©poque Ã©poque Minimum Pas Trouver Est Passã© Est Ã©poque Ã©poque Minimum Minimum Ã©poque Minimum Minimum Ã©poque Ã©poque Ã©poque Ã©poque Instant Ã©poque Ã©poque Trouver Est Est Ã©poque Minimum Grand Avant Instant Instant La Trois Trois Trois Trois Trois Instant Instant Celui Instant Instant Instant Instant Instant Partir Partir Partir Bien Partir Partir Partir Petit Venir Partir Petit Bien Petit Petit Petit Comment Petit Comment Comment Nuit Nuit Partir Partir Maintenant Le Le Comment Comment Nuit Nuit Nuit Nuit Nuit De Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre De De Ã Ã Ã Ã Ã Ã
# id: cefc-tcof-Aqua_05-119
# hyp: Pas Avoir Pour Pour Avoir Rã©flã©chir Voir Piã¨ce Parce Prochain Prochain Sur Ville Plus Devoir Piã¨ce Dire Corps Si Si Prochain Devoir Aller Ãªtre Quand Quand Ils Petit Petit Passã© Elle Passer Dire Quand Ils Petit Passã© Celui Me Ãªtre Fois Quand Quand Non Passã© Me Ãªtre Ãªtre Quand Quand Quand Quand But But Cours Dire Cours Cours Petit Plus Non Seconde Seconde Petit Trop Alors Alors Notre Association Mettre Mettre Mettre Comment Comment Comment A A A A A Cours A A Passer Du Du A A Ou Heureusement Heureusement Heureusement Heureusement Du Du Du Aprã¨s A A A A A A A A A A A A A A A A Personne A
# id: cefc-tcof-Aqua_05-164
# hyp: Par Lucratif Trop Corps Corps Parler Prendre Mettre Passã© Lucratif Lucratif Mettre Mettre Prendre Parler Lucratif Lucratif Non Non Parler Parler Lucratif Aprã¨s Heureusement Heureusement Ils Ils Aprã¨s Lui Une Parler Parler Une Dire Dire Parler Une Ils Et Parler Une Une Ils Lui Une Une Ils Me Une Une Quand Ils Une Alors Une Ils Dire Dire Ils Quand Que Pour Ils Que Lucratif Lucratif Oui Un Non Ã Lucratif Mettre Quelqu'un Quelqu'un But Que <oov> <oov> <oov> <oov> Quoi Lucratif But Quand Ils Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Au Parler Rã©flã©chir Rã©flã©chir Rã©flã©chir Du Mettre Celui Mettre Mettre Ils Celui Parler Parler Parler Trop
# id: cefc-tcof-Aqua_05-177
# hyp: Pouvoir Aprã¨s Aprã¨s Quelqu'un Plus Aprã¨s Savoir Comme Au A A Aprã¨s Savoir Tu Y A A Du Aprã¨s Tu A A Devoir Du Du Savoir Lui Vois Elle Du Aprã¨s Aprã¨s Savoir Haut Lui Devoir A A Aprã¨s Mon Devoir Tout Tout Tout Devoir Devoir Tout Sur Sur Sur Sur Mon Vouloir Vouloir Sur Oui Vouloir Vouloir Ã Oui Au Vous Une Oui Oui Oui Oui Une Mon Mon Vous Vous Pour Pour Pour Oui Oui Mon <oov> <oov> <oov> <oov> Vous Mon Mon Mon Mon Mon Mon <oov> <oov> <oov> <oov> Mon Lui Heureusement Vous Vous Vous Oui Oui Truc Dans Dans Pour Oui Vous Oui Dans Dans Dans Ou Ou Ou Ou Ou Ou Ou Ou Ou Oui Oui Oui Oui Oui Oui Dans Ou
# id: cefc-tcof-Aqua_05-181
# hyp: Corps Trop Mãªme Semaine Cours Heure Amã©liorer Le Semaine Semaine Heure Voiture Monter Beau Cours Faire Heure Matin Demi Cours Dã©cider Matin Me Cheval Cheval Non Nous Nous Ã Notre Son Son Non Parler Beaucoup Beaucoup Son Parler Parler Beaucoup Son Parler Parler Garã§on Garã§on Garã§on Garã§on Garã§on Garã§on Garã§on Garã§on Garã§on Garã§on Monde Nuit Nuit Nuit Nuit Nuit Monde Ces Nuit Cours Cours Cours Cheval Ces Nuit Nuit Nuit Nuit Ces Ces Nuit Nuit Nuit Nuit Nuit Nuit Nuit Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces 1000 1000 1000 Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces 1000 1000 Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces Ces
# id: cefc-tcof-Aqua_05-198
# hyp: Toi Ou Au Passã© Ou Lã Sur Quelqu'un Celui Ou Lã Que Celui Avoir Ou Le Lã Lã Oui Exact Alors Toi Alors Le Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Alors Exact Exact Devoir Devoir Alors Alors Alors Alors Alors Alors Alors Alors Alors Devoir Devoir Quoi Quoi Et Quoi Quoi Alors Alors Alors Alors Alors Alors Alors Alors Quoi Alors Quoi Quoi Quoi Quoi Une Quoi Aller Quoi Quoi Alors Alors Les Passã© Une Une Une Une Une
# id: cefc-tcof-Aqua_05-205
# hyp: Que <oov> Avec Plusieurs Autre Autre Lã Il Nous Vouloir Autre Les Oui Fois Sur Il Nous Alors Prochain Voir Alors Alors Quoi Quoi Quoi Quoi Quoi Voir Quoi Quoi Devoir Quoi Une Une Pouvoir Quoi Quoi Aller Aller Quoi Pouvoir Quoi Quoi Pouvoir Pouvoir Quoi Quoi Pouvoir Quoi Quoi Quoi Pouvoir Devoir Ãªtre Devoir Devoir Il Devoir Ã Ãªtre Toi Alors Il Il Nous Une Une Une Nous Nous Nous Alors Prochain Alors Oui Celle Les Les Prochain Il Il Nous Nous Nous Nous Alors Me Me Dire Dire Dire Dire Alors Alors Dire Dire Oui Me Me Alors Une Alors Alors Alors Me Celui Dire Celui A A A A A A A A <oov> Passã© A A A A A A Ã A
# id: cefc-tcof-Aqua_05-209
# hyp: Le A Toi Une Nous Nous <oov> <oov> Avoir A Passã© Passã© Celui Les De <oov> <oov> Avoir Pour Dans Passã© Passã© Passã© <oov> <oov> Celui Celui Passã© Le Le Y Pour Celui Celui Celui <oov> De De De Pour Pour <oov> <oov> <oov> <oov> <oov> <oov> Celui Celui Il Il Toi Il Passã© Passã© Passã© Passã© Passã© Toi Passã© Au Au Passã© Passã© Passã© Passã© Passã© Passã© Passã© Oui Non Non Ã Oui Oui Passã© Non Non Non Non Non Il Il Ã Ã Ã Non Non Non Non Non Non Non Non Non Non Non Non Non Non Ã Non Non
# id: cefc-tcof-Aqua_05-214
# hyp: Autre Parce Commencer Gens Parler Aimer Prochain Quand Quand Une Bien Parce Place Une Ton Seconde Lã Lã A Plusieurs Lã Aller Aller A Devoir Aimer Aimer Une Aller Aimer Aimer Aimer Plusieurs Une Vois Quoi A Groupe Aller Aller Groupe Sortir Aller Quoi Quoi Quoi Quoi Quoi Aller Aller Aller Aller Le Une Aller Aller Inventer Inventer Journã©e Une Une Une Inventer Trop Trop Se Du Aprã¨s Aprã¨s Savoir Mois Arrive Se Arrive Place Place Place Elle Comme Comme Plusieurs Plusieurs Il Mois Mois Mois Mois Ou Passer Comment Plusieurs Plusieurs Une Une Lã Le Le Le Jamais Retourner Retourner Jamais Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Retourner Rien A Mois Mois Parce
# id: cefc-tcof-Aqua_05-227
# hyp: Vous Du Truc Vous Vous Parce Avoir Passã© Celui Cã´tã© Quand Parce Ãªtre Grand Cã´tã© Passã© Dire Parce Tout Haut Mon Mon Mon Dire Dans Par Par Mon Mon Mon Corps Mon Mon Mon Mon Mon Mon Grand Mon Mon Mon Parce De Grand Quand Corps Corps Mon Grand Grand Grand Grand La La La La Grand Corps Corps Mon Mon Mon Mon Mon Corps Corps Corps Corps Passã© Corps Que Cã´tã© Mon Cã´tã© Mon <oov> Que Mon Mon Mon Mon Celui Cã´tã© <oov> Que Cã´tã© Cã´tã© Dire Parce Parce Parce Dire Dire Trois Dire Dire Ils Pour Trois Trois Ã Trois Pour Pour Pour Haut Haut Haut Corps Corps Corps Haut Haut Mon Mon Mon Mon Corps Trois Trois Trois Trois Trois Trois Trois Trois Trois Trois
# id: cefc-tcof-Aqua_05-25
# hyp: Passer Corps Place Au Au Venir Travailler Que Elle Avoir Devoir Cã´tã© A Non Trois Trouver Grand Une Truc Trois Trois Travailler Les Avoir La Passer Cã´tã© Au Avoir Passer De Celle Celle Avoir Aller Celle Celle Les Association Les Les Les Devoir Ce Les Les Les Les Les Les Les Ce Ce Les Leur Lucratif Lucratif Une Une Une Mettre Plusieurs Plusieurs Plusieurs Et A A A A Passã© Donner Trois Travailler Travailler La Trois Trois A A Plusieurs Maintenant Cã´tã© Cã´tã© Travailler Travailler Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Dire Dire Quand Quand Haut Haut Elle Elle Trop Mettre Quand Quand De De Avec Exact Quand Plus Plus Plus Avec Avec Avec Avec Plus Avec Avec Avec Avec Avec Plus Plus Plus Avec Avec Avec Avec Place Trois
# id: cefc-tcof-Aqua_05-299
# hyp: Autres Autres Essayer Essayer Autres Ou Truc Rien Rien Autres Autres Ou Ou La Journã©e Autres Au Trois Essayer Essayer Autres Autres Le Seconde Rien Autres Autres Chaque Beaucoup Beaucoup Annã©e Personne Chaque Beaucoup Essayer Journã©e Autres Beaucoup Son Place Lucratif Seconde Seconde Beaucoup Essayer En Autres Autres Autres Autres Autres Autres Autres Journã©e En En Journã©e Journã©e Journã©e Journã©e Faire Annã©e Le Au Au Toi Faire <oov> Le Le <oov> Plus Avec Avec Dans Avec Avec Dans Autres Faire Faire Faire Un Un Un Lã Le Aprã¨s Aprã¨s Travailler Avec Autres Autres Autres Autres Autres Autres Autres Trois Trois Lã Lã Que Une Que Que Que Que Alors Alors Alors Du Du Du Lã Que Que Que Que Que Que Que Que Du Lã Lã Lã Rien
# id: cefc-tcof-Aqua_05-312
# hyp: Ã©poque Passã© Commencer Beaucoup Groupe Sortir Passer Du Savoir Groupe Une Alors Se Ville Groupe Corps Me Passã© Minimum Groupe Vous Demander Demander Sortir Groupe Du Truc Leur Demander Groupe Groupe Place Ce Groupe Groupe Groupe Place Ce Minimum Groupe Groupe Groupe Ce Autre Demander Place Ce Ou Donner Donner Donner Donner Donner Place Place Truc Place Place Vous Ensemble Me Me Demander Ce Demander Demander Et Et Les Les Les Celle Avoir Celle Celle Oã¹ Celle Celle Avoir Avoir Celle Celle Celle Avoir Avoir Avoir Avoir Avoir Avoir Avoir Celle <oov> Celle Celle Celle Avoir Me Me Celle Avoir Celle Avoir Avoir Avoir Avoir Les Les Grand Grand Avoir Avoir Celle Celle Celle Celle Celle Avoir Avoir Avoir Celle Celle Les Les Les Les Avoir Avoir Avoir
# id: cefc-tcof-Aqua_05-56
# hyp: Savoir Que Trop Trop Oui Chaque Chaque Se Mettre Faire A Chaque Chaque Mettre Ãªtre Lã Lucratif Parler Annã©e Au Non Lucratif Pouvoir Exact Ãªtre Passer But Exact Annã©e Que But Venir Prendre But Lucratif De Pouvoir Prendre Lucratif <oov> Pouvoir Pouvoir Voir Passer Comme Pouvoir Voir Au Au Pouvoir Voir Au Faire Aller Voir Un Un Passer Arrive Deux Passer Un Oui Arrive Arrive Oui Passer Passer Passer Passer Venir Venir Mettre Du Passer Passer Passer Passer Passer Passer Passer Tout Passer Oui Passer Passer Vois Vois Vois Plusieurs Venir Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Venir Venir Venir Venir Venir Venir Passer Passer Passer Venir Venir Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer Passer
# id: cefc-tcof-Aqua_05-99
# hyp: Sur Association Dans Fois Ou Aprã¨s Savoir Corps Oui Toi Vous Association Aprã¨s Les Et Passã© Nous Corps Oui Ãªtre Y Nous Corps Par Par Par Corps Nous Par Par Corps Par Par Par Mãªme Mãªme Mãªme Par Nous Par Par Par Par Par Par Par Par Mãªme Par Par Par Par Par Par Par Par Ã Ã Passã© Ã Ã Nous Non Nous Nous Ã Nous De Oui Toi Toi Toi Toi Non Toi Il De Nous Elle Ã Non Nous Il Il Le Le Le Le Le Le Le Le Prochain Vouloir Vouloir Sur Sur Sur Le Le Heureusement Heureusement Heureusement Heureusement Heureusement Heureusement Heureusement Heureusement Vois Vois Vois Vois Vois Vois Vois Vois Vois Heureusement Vois Plusieurs Une Association Passã© Passã© Comme Alors Pour Association
# id: cefc-tcof-Assemblee_dim_08-25
# hyp: Aprã¨s Aprã¨s Aprã¨s Aprã¨s Ã©tudier Ils Va Du Vous Aprã¨s Groupe Groupe Groupe Peu Quelqu'un <oov> Que Dur Pendant Le Oui Journã©e Avec Deux Vie Et Et Instant Donner Commencer Partir Partir Instant Instant Et Toi Instant Instant Gens Maintenant Petit Jamais Quoi Quoi Bien Instant Instant Instant Gens Quoi Quoi Pouvoir Pouvoir Instant Autres Gens Quoi Pouvoir Se Partir Instant Gens Quoi Retourner Retourner Jamais Retourner Retourner Vois Truc Ses Savoir Savoir Savoir Savoir Savoir Heureusement Infã©rieur Stage Va Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Vois Vois Vois Vois Vois Vois
# id: cefc-tcof-Assemblee_dim_08-9
# hyp: Non Non Passã© Passã© Oui Un De Les Ã Toi Oui Oui Si Avoir Les Nous Nous Ã Ã Y Toi Dans Dans Fois Quand Prochain Prochain Avec Avec A Quoi Quoi Avec Avec Quelqu'un Fois Quoi Pour Pour Quelqu'un Ãªtre Quoi Quoi Avec Pour Elle Pouvoir Pouvoir Pouvoir Pouvoir Quoi Quoi Quoi Aller Devoir Le Pouvoir Quoi Non Dans Fois Dans Dans Au Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Au Passã© Passã© Au Au Au Au Au Au Non Passã© Au Au Passã© Passã© Non Non Non Non Non Non Non Non Non Non Non Plusieurs Au A Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un Quelqu'un
# id: cefc-tcof-Assemblee_mau_08-17
# hyp: Bien Plusieurs Ã Aller Non Savoir Aller Un Ils Ils Mettre Mettre Il Toi Devoir Au Une Haut Ã Ã Prendre Les Les Avoir Fois Mãªme Mãªme Passer Exact Les Ou Truc Prochain Fois Fois Plus Prochain Prochain Ou Ou Voir Lã Exact Voir Voir Que Que Que <oov> Prochain Prochain Que Que Au Au Lã Oui Celle Avoir Passer Commencer Les Maintenant Gens Leur Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Maintenant Gens Maintenant Maintenant Maintenant Beaucoup Beaucoup Gens Gens Gens Gens Corps Corps Mon Mon Mon Vois Vois Vois Vois Vois Mon Vois Mon Mon Mon Gens Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon Mon
# id: cefc-tcof-Assemblee_mau_08-79
# hyp: Me Pour Pour Toi Passã© Celui Avoir Avoir <oov> Toi Faire Non Que Que <oov> <oov> <oov> Celui Au Que <oov> <oov> Un Un Oui Oui Oui Une Plusieurs Ãªtre Pour Il A A Il Il Il Ils Ils Quand Dire Dire Dire Il Il Il Nous <oov> Un Un Oui Oui Alors Une Une Plusieurs Pour <oov> Me Me Plusieurs Plusieurs Celle Avoir Celle Celle Celle Celle Dire Dire A Avoir Celui Celle Celle Dire Dire A Celui Dire Dire Dire Dire Dire Quand Dire Dire Dire Dire Dire Dire Dire Dire Dire Dire Dire Dire Celle Celle Celle Celle Celle Celle Celle Celle Celle Dire Dire Dire Dire Celle Celle Celle Oui Oui Oui Oui Alors Alors Oui Oui Oui Oui Oui Oui Oui Alors
# id: cefc-tcof-Assemblee_mul_08-70
# ...
# id: cefc-tcof-sophieetcathy-16
# hyp: Prochain Une Y Plusieurs Plusieurs A Alors Alors Oui Il Au Les Les Nous Une Alors Oui Ils Oui Nous Il Il Les Les Les Prochain Oui Oui Un Un Nous Il Au Avoir Avoir Celle Oui Oui Un Un Faire Faire Faire Au Au Avoir Et Un Un Faire Faire Faire Au Au Avoir Et Les Nous Il Il Au Au Avoir Les Les Il Au Au Avoir Celle Les Ãªtre Ãªtre De Le Me Me Ãªtre Avoir Avoir Les Me Avoir Avoir Celle Il Avoir Avoir Celle Au Au Au Au Au Avoir Avoir Au Au Et Avoir Avoir Celle Avoir Au Au Avoir Avoir Avoir Avoir Avoir Avoir Avoir Avoir Avoir Avoir Celle Avoir Et Et Les Avoir Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs
# id: cefc-tcof-sophieetcathy-20
# hyp: Que Et Pour Pour Pour Une Oui Celle Celui Passã© Dans Tout Tout Parce Faire Celle Celui Celui Non Non Ã Ã Au Au Le Lã Ã Ã Ã Que Au Au Le Lã Lã Nous Tout Tout Quand Quand Elle Lã Lã Lã Ã Nous Au Que Tout Le Lã Nous Nous Nous Nous Le Lã Que Tout Tout Lã Lã Lã Que Lã Le Le Lã Au Le Le Le Pour Le Le Lã Non Pour Pour Pour Pour Le Lã Ã Le Lã Le Le Lã Le Lã Lã Lã Lã Lã Non Et Lã Lã Pour Celui Lã Pour Lã Lã Lã Lã Lã Lã Lã Lã Lã Lã Le Le Avoir Celui Celui Celui Celui Me Me Me Me Pour Pour Pour Pour
# id: cefc-tcof-sophieetcathy-64
# hyp: <oov> Mon Mon Parce Parce Passã© Au Au Vois A A Ã Ã Tout Avoir Au Si Pour Pour Fois Dans Dans Faire Ils Ils Ils Ã Mon Vois Heureusement Dans Dans De Parce Parce Tout Non Non Passã© Passã© De Parce Parce Parce Parce Passã© Me Ãªtre De Fois Fois Nous Ã Non Non Ã Ã Ã Ã Ã Exact Exact Exact Exact Exact Comme Pour Toi Exact Les Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Il Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Celle Que Prochain Que Prochain Prochain Prochain Prochain Que Que
# id: cefc-tcof-vacances-112
# hyp: Annã©e Lucratif But Une Son Lucratif <oov> Problã¨me Gens Alors Groupe Groupe Personne Une Alors Alors Son Lucratif Personne Sortir Vois Bien Bien But But Mon Rã©flã©chir Ton <oov> Que But Rã©flã©chir Celle Son <oov> <oov> Que Nous Les Son Son Rã©flã©chir Nous But Son Son Comme Les Les Celle Beaucoup Le Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir But But Bien Bien Bien Bien Rã©flã©chir Bien Bien Bien Avoir Au Au Au Au Au Au Au Au Au Au Au Au Ton Ton Ton 00 00 Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ã§a Ton Ton Rã©flã©chir Ton Ton
# id: cefc-tcof-vacances-115
# hyp: Plusieurs Nous Ãªtre Quelqu'un Rã©flã©chir Toi Nous Quelqu'un Plus Ou Plusieurs A Voir Exact Lui Au Rã©flã©chir Il Ã Lui Lui Ã Ã Nous Nous De De Que Que Le Nous Nous Que Lã Le Le Nous Lã Heureusement Lã Lã Le Lã Nous Le Le Nous Heureusement Nous Heureusement Heureusement Heureusement Quoi Nous Heureusement Lui Nous Nous Nous Lui Rã©flã©chir Rã©flã©chir Au Rã©flã©chir Dire Dire Rã©flã©chir Dire Au Sur Nous Nous Nous Nous Nous Nous Nous Nous Nous Au Au Sur Sur Rã©flã©chir Rã©flã©chir Rã©flã©chir Celui Passã© Du Du Du Du Du Celui Celui Nous Nous Nous Nous Nous Nous Nous Nous Au Rã©flã©chir Il Il Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois Vois
# id: cefc-tcof-vacances-140
# hyp: Leur Quelqu'un Gens Sortir Ville Truc Truc <oov> Mois Aimer Quelqu'un Truc Truc Mois Lui Exact Plus Vous Truc Ville Quelqu'un Quelqu'un Quelqu'un Bien Truc Ville Quelqu'un Quelqu'un Quelqu'un Chaque Truc Quelqu'un Quelqu'un Exact Chaque Comme Ville Quelqu'un Plus Toi Comme Comme Quelqu'un Avec Il Il Il Voir Quelqu'un Quelqu'un Autre Autre Quelqu'un Quelqu'un Quelqu'un Ville Quelqu'un Ville Ville Ville Ville Sur Aller Vois Mon Mon Mettre Mettre Mettre Mettre Pouvoir Pouvoir Pouvoir Pouvoir Pouvoir Mon Mon Quoi Quoi Quoi Quoi Quoi Quoi Quoi Quoi Vois Quoi Vois Vois Mon Quoi Quoi Pouvoir But But Savoir Savoir Savoir Savoir Aprã¨s Aprã¨s Aprã¨s Mon
# id: cefc-tcof-vacances-154
# hyp: S'en Vouloir Seconde But Emploi Dire D'accord Trois Annã©e C'est Ensemble Trois Trois Oã¹ Alors Alors Question Corps Oã¹ Le Le Question Question Seconde Parler Le Le Question Seconde Chaque Le Le Monter Question Monter Monter Monter Monter Monter Monter Monter Beaucoup Monter Monter Monter Seconde Seconde De Monter Seconde Seconde Parler Parler Seconde Seconde Parler Dã©cider Seconde Parler Dã©cider Dã©cider Donner Dã©cider Partir Donner Donner Partir Partir Comment Comment Comment Alors Gens Maintenant Ã§a Ã§a Ã§a De Au Journã©e Essayer Essayer Essayer Non Dedans Dedans Bien Bien Bien Attendre Attendre Attendre Attendre Dedans Au Mettre C'est C'est C'est C'est
# id: cefc-tcof-vacances-21
# hyp: Dire Quoi Alors Passã© Comme Truc Rã©flã©chir Du Quand Tout Comme Ou Truc Plusieurs Tout Comme Comme Passã© Plusieurs Avoir Comme Comme Du Plusieurs Truc Truc Vous Vous Plusieurs Du Comme Vous A Vous Aller Aller Vous A A Aller Devoir Plusieurs A Rã©flã©chir Devoir Si Plusieurs A Vous Si Si Si Si Si Si Si Au Si Si Si Si Comme Comme Vous Comme Comme Quelqu'un Comme Avoir Celle Celui Celui Passã© Comme Avoir Comme Comme Celui Celui Avoir Avec Quelqu'un Comme Celle Les Plus Plus Plus Autre Autre Autre Autre Autre Autre Comme Comme Comme Avec Avec Plus Plus Plus Comme Comme Comme
# id: cefc-tcof-vacances-35
# hyp: Avec Corps Trop Trop Mon Au Trop Rã©flã©chir Pour Comme Dans Tout Dire Dire Association Rã©flã©chir Truc Y Y Comme Mon Association Association Rã©flã©chir Haut Tout Parce Parce Comme Elle Elle Vous Rã©flã©chir Haut Aprã¨s Tout Tout Tout Tout Tout Parce Elle Elle Vois Association Heureusement Tout Comme Tout Tout Tout Tout Parce Du Mon Haut Vois Tout Tout Tout Tout Haut Heureusement Lui Rã©flã©chir Rã©flã©chir Association Vois Parce Y Y Mon Mon Mon Mon Mon Mon Celui Tout Tout Tout De Vous Le Lã Parce Association Lã Vous Dire Y Dire Dire Parce Lã Lã Lã Tout Lui Dire Rã©flã©chir Rã©flã©chir Rã©flã©chir Rã©flã©chir Tout Tout Tout Tout
# id: cefc-tcof-vacances-90
# hyp: Heureusement But But But <oov> Et Me Me But Vois Quoi Les Au Ãªtre Il Quoi Pouvoir Bien Et Quelqu'un Ãªtre Petit Bien Bien Plus Avec Quelqu'un Bien Bien Bien Avoir Au Faire Un Rã©flã©chir Bien Celle Celle Avec Quelqu'un Quelqu'un Celle Petit Celle Avec Quelqu'un Quelqu'un Trop Trop Bien Bien Bien Bien Bien Avec Quelqu'un Quelqu'un Plus Plus Celle Plus Les Les Celle Celle Celle Au Me Parler Aller Parler Parler Quoi Parler Parler Parler Parler Parler Parler Parler Savoir Tout Celle Ãªtre Celle Les Les Les Celle Celle Avoir Au Savoir Savoir Savoir Parler Quelqu'un Celle Quelqu'un Quelqu'un Quelqu'un Quelqu'un Celle Celle
# id: cefc-tcof-voyage_USA-109
# hyp: Trop Chaque Chaque Quoi Comme Chaque Chaque Rã©flã©chir Vous Dans Mon Pouvoir Comme Mettre Rã©flã©chir Rã©flã©chir Rã©flã©chir Truc Mon Quoi Mettre Mettre Haut Passã© Rã©flã©chir Truc Mettre Quoi Devoir Devoir Devoir Ãªtre Rã©flã©chir Comme Comme Quelqu'un Pouvoir Elle Elle Pouvoir Quoi Prochain Prochain Prochain Ou Ou Voir Voir Voir Dans Ou Ou Ou Ou Ou But Quoi Quoi Mettre Mettre Mettre Mettre Mettre Mettre Haut Haut Ou Ou Ou Ou Ou But But Quoi Pouvoir Quoi Aller Devoir Devoir Ou Tu Lucratif Lucratif But Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif But But Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Lucratif Ville Lucratif Lucratif Lucratif But Ville Lucratif Lucratif Lucratif Ville Ville Ville Ou Ou Ou Ou Ville Ville Ou Ou
# id: cefc-tcof-voyage_USA-148
# hyp: Lucratif Lucratif Ton Passã© Que Que Bien Les Alors Une Trop Quand Quand Association Avoir Avoir Annã©e Une Plusieurs Elle Heureusement Prochain Seconde Seconde Dans Dans Tout Tout Tout Elle Elle Prochain Prochain Petit Fois Dans Dans Dans Deux Deux Bien Bien Bien Bien Bien Bien Bien Bien Petit Petit Association Petit Petit Petit Petit Fois Dans Dans Dans Tout Dans Tout Tout Dans Dans Dans Dans Dans Prochain Fois Prochain Elle Elle Elle Celle Quand Quand Plusieurs Plusieurs Celle Vois Heureusement Prendre Fois Fois Dans Elle Celle Elle Elle Plusieurs Plusieurs Heureusement Comme Avoir Une Une Une Une Une Une Une Une Avoir Avoir Avoir Avoir Avoir Avoir Rã©flã©chir De De De Tu Tu De De De De De De De De De De De De De
# id: cefc-tcof-voyage_USA-154
# hyp: <oov> Que Que Celle Les <oov> Il Toi Ils <oov> Le Le Celui Celui Celui Me Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Me Celui Me Me Quand Parce Parce Nous Nous Nous Alors Alors Alors Parce Parce Nous Nous A Ãªtre Oui Quand Quand Alors Alors Me Ãªtre A A Quand Quand Quand Une Les Les Ã Les Et Ãªtre Ãªtre Nous Il Il Me Ã Nous Me Me Me Ã Me Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Le Ãªtre Ãªtre Ãªtre Lã Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre De Le De De Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre De De De Ãªtre Ãªtre Ãªtre Ãªtre Ãªtre Au Au Ãªtre Ãªtre Ãªtre Au Au Au Au Au Ãªtre Ãªtre Au Au Ãªtre Ãªtre Ãªtre Ãªtre
# id: cefc-tcof-voyage_USA-185
# hyp: Parce Toi Un Oui Oui Oui Un Oui Une Une Pouvoir Pouvoir Toi Il Ã A Une Une Une Toi Il Avoir Avoir Dire Parce Prochain Prochain Il Ã Au Faire Dire Parce Prochain Prochain Prochain Comme Faire Faire Dire Parce Il Prochain Prochain Comme Comme Dire Parce Parce Avoir Prochain Elle Comme Parce Parce Dire Prochain Prochain Comme Parce Parce A Prochain A A A A A A Non Il Passã© Passã© Passã© Ãªtre Plusieurs Une De Passã© Non Passã© Passã© Non Non Non Ãªtre Plusieurs Plusieurs Plusieurs Plusieurs A Parce A A A A A A A A Plusieurs Une Une Plusieurs Alors Toi Non Non A A Le Le Le De De De Plusieurs Alors Alors Alors Alors Alors Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs A
# id: cefc-tcof-voyage_USA-188
# hyp: Arrive Devoir Corps But But Celui Annã©e Annã©e But Mon Dire Passã© A Avoir Avec Et Tu A A A Une Une Et Au Arrive Parce Parce Deux Deux Seconde Lucratif Comme Comme Parce Un Un Seconde Parler Comme Comme Parce Un Un Mettre Parler Trop Comme Un Un Beaucoup Seconde Lucratif Lucratif Deux Deux Beaucoup Parler Un Un Faire Seconde Parler Faire Faire Au Parce Faire Faire Au Parce Plusieurs Plusieurs Plusieurs A A A A A A Y Parce Parce Parce Parce Ã A A Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã A A Quoi Quoi Quoi Ã Quoi Quoi Quoi Quoi Pouvoir Pouvoir Du Du Du Du Du Du Du Du Du Du
# id: cefc-tcof-voyage_USA-207
# hyp: Quand Quand Quand Quand Quand Ã Que Le Ils Ils Quand Quand Non Non De Et Et Celui Passã© Non Ãªtre Ãªtre Le Le Pour Passã© Quand Pour Ils Pour Ils Quand Quand Quand Ils Ils Quand Ils Quand Ils Ils Ils Quand Quand Quand Quand Quand Quand Ils Ils Quand Quand Quand Quand Ils A Celle Celle Les Les A A A A A Il Il Il Il Il Il Il Il Nous Nous Passã© Passã© Passã© Ã Ã Nous Nous Nous Il Celle Celle Celle Celle Celle Celle Celle Celle Les Les Celle Celle Celle Celle Celle Celle Celle Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs A Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Plusieurs Celle Celle Plusieurs Celle Celle
# id: cefc-tcof-voyage_USA-28
# hyp: Une Il Une Alors Oui Oui Oui Oui Alors Alors Pour Alors Oui Oui Oui Avoir Celle Oui Oui Oui Alors Alors Alors Alors Alors Alors Oui Alors Le Le Le Lã Que Alors Au Oui Oui Le Le Que Que <oov> Passã© Alors Alors Alors Alors <oov> <oov> Avoir Avoir Au Au Que Que Que Avoir Les Avoir Que Que Au Non Lã Que Passã© Passã© Le Lã Lã Le Le Le Oui Le Oui Lã Passã© Lã Lã Lã Lã Que Lã Oui Que Celui De De Passã© Passã© Passã© Passã© Oui Oui Que Celui Passã© Celui Passã© Passã© Celui Celui Lã Lã Celui Passã© Celui Celui Celui Passã© Passã© Celui Passã© Passã© Me Me Celui Celui Celui Celui Celui Celui Celui Celui Celui Celui Celui
# id: cefc-tcof-voyage_USA-3
# hyp: Ãªtre Dã©cider Place Ãªtre Ãªtre Vous Vie Chaque Chaque Leur Travailler Quand Rã©flã©chir Beaucoup Maison 00 Chaque Oã¹ Et Ce Travailler Travailler Mes Est Mettre Mettre Ãªtre Grand Grand Il D'accord Passer Passer Mettre Me Grand Grand Grand Grand Venir Venir Trop Celui Mettre Toi Grand Grand Passer Passer Comment Comment Mettre Voir Personne Mettre Mettre Trouver Ville Mettre Mettre Me Me Faire Faire Faire Faire Ãªtre Ãªtre Chaque Beaucoup Et Ãªtre Chaque Son D'accord D'accord Son Son D'accord Travailler Beaucoup Beaucoup Beaucoup Beaucoup Beaucoup Beaucoup Beaucoup Beaucoup Son Son Avoir Avoir Son Travailler Travailler Mon Choix Choix Choix Choix Choix Celle Celle Les Les Les Et Et Et Et Les Les Les Minimum Minimum Minimum Que Que Que Que Que Que Que Que Que Que Que Que
# id: cefc-tcof-voyage_USA-33
# hyp: Me Me Que Avec Aller Dire De De Sur Sur Ou Quelqu'un Plus Sur Autre Autre Avec Sur Sur Y Avec Avec Devoir Devoir Plus Plus Avoir Devoir Plusieurs Avec Avec Devoir Devoir Plus Avec Avec Devoir Plus Plus Avec Avec Autre Plus Avec Avec Avec Autre Avec Avec Avec Avec Quelqu'un Quelqu'un Avoir Quelqu'un Sur Sur Sur Sur Sur Sur Sur Faire Au Oui Sur Sur Parce Parce Parce Un Un Un Un Oui Oui Oui Oui Il Il Il Un Oui Oui Parce Parce Il Un Il Il Il Il Il Sur Parce Parce Parce Parce Avec Parce Parce Dire Il Dire Dire Dire Dire Il Il Il Toi Toi Il Plus Plus Plus Plus Plus Plus Plus Plus Plus Plus Plus Plus Avec Avec Plus
# id: cefc-tcof-voyage_USA-58
# hyp: Celui Celui Passã© Passã© Avoir Celle Lã Passã© Ils Quand Parce De Celui Celle Quand Quand Passã© Avoir Celle Celle Celle Avoir Avoir Avoir Celle <oov> Avoir Avoir Avoir Celle Celle Avoir Avoir Avoir Celle Celle Avoir Avoir Celle Celle Celle Celle Avoir Celle Celle Celle Celle Celle <oov> Celle Avoir Celle Celle Avoir Avoir Celle Il Celle Celle Celle Celle Celle Celle Celle Dire Dire Passã© Passã© Celui Passã© Passã© Passã© Quand Passã© Passã© Passã© Passã© Passã© Passã© Passã© Passã© Passã© Alors Oui Oui Oui Oui Oui Il Il Il Nous Nous Oui Passã© Ã Ã Oui Non Ã Oui Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Ã Nous Ã Nous Nous
# id: cefc-tcof-voyage_USA-64
# hyp: Pouvoir Vous Vous Pour Devoir Vous Oui A Y Exact Oui Oui Nous Exact Alors Oui Nous Oui Oui Ã Nous Nous Oui Ã Ã Nous Nous Ã Ã Nous Nous Ã Ã Nous Nous Ã Nous Nous Nous Nous Ã Nous Nous Nous Tout Nous Il Nous Ã Oui Ã Ã Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous De De De Nous Y De Ã Nous Ãªtre Ãªtre Nous Ã De De Ã Ã Ã Si Si Si Si Si Si Si De De De Si Si Si Si Si Ã Ãªtre Ãªtre De De De De De De De De De De De De De De De De De De De De De De De De De De De De De De De
# id: cefc-tcof-voyage_USA-66
# hyp: <oov> Voir A Un Plusieurs Celui Ãªtre De Que Le A A A Parce Plus Exact Un De Le Lã Celui Celui Me Me Voir Devoir <oov> Que Lã Plus Plus Plus Exact Devoir Devoir Et Et Lã Lã Plus Voir Celui Celui Celui Que Que Que Voir Voir Devoir Celui Que Que Que Que Exact Me Plus Exact Exact Que Lã Exact Plus Plus Lã Lã Le Le Plus Le Le Plus Plus Lã Lã A A Pour Pour Ils Que Que Avoir Avoir Celle Pour Pour Pour Pour Pour Pour Ã Non Non Non Non Non Non Non Les Ã Les Les Et Et Et Et Ã Ã Ã Et Non Non Non Non Ã Ã Ã Ã Ã Ã Ã Non Ã Ã
# id: cefc-tcof-voyage_USA-7
# hyp: Passer Passer Ce Trouver Vous Cã´tã© Grand Trouver Est Personne Ou Trouver Travailler Ã©poque Truc Grand Trouver Ã©poque Est Grand Grand Travailler Est Est Truc Cã´tã© Travailler Cã´tã© Grand Grand Cã´tã© Passer Passer Cã´tã© Ou Ou Passer Passer Passer Truc Passer Passer Passer Passer Truc Passer Passer Ou Truc Truc Est Venir Truc Tu Ã©poque Tu Haut Ã©poque Est Haut Vous Tu Grand Grand Grand Grand Grand Rã©flã©chir Rã©flã©chir Rã©flã©chir Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Grand Trois Grand Grand Grand Trois Trois Trois Trois Trois Trois Vouloir Sur Sur Sur Sur Sur Vouloir Vouloir Vouloir Vouloir Sur Sur Sur Sur Sur Sur Vouloir Vouloir Vouloir Vouloir Vouloir Vouloir Vouloir Vouloir Vouloir Vouloir
# run.json and run.zip created successfully.

# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score

# Smooth function for BLEU score
smooth = SmoothingFunction().method4

# Assuming decoded_predictions is a list containing the decoded predictions generated by your model
# And hypotheses is a list containing the ground truth hypotheses

# Preprocess hypotheses to match the format expected by corpus_bleu
references = valid_target_sequences

# Preprocess decoded_predictions to match the format expected by corpus_bleu
decoded_predictions_tokenized = [np.unique(hyp.split()) for hyp in hyp_valid]

# Calculate BLEU score with smoothing
bleu_score = corpus_bleu(references, decoded_predictions_tokenized, smoothing_function=smooth)

print("BLEU Score with smoothing:", bleu_score)

# Download NLTK resources if not already downloaded
nltk.download('wordnet')

# Tokenize references
tokenized_references = [word_tokenize(ref) for ref in valid_target_sequences]

# Tokenize hypotheses
tokenized_hypotheses = [word_tokenize(hyp) for hyp in hyp_valid]

# Calculate METEOR score
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(tokenized_references, tokenized_hypotheses)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print("Average METEOR Score:", average_meteor_score)

# Prepare data for JSON
output_data = {
    "BLEU Score with smoothing": bleu_score,
    "Average METEOR Score": average_meteor_score
}

# Write output_data to a JSON file
with open("prediction.json", "w") as json_file:
    json.dump(output_data, json_file)

print("Evaluation results written to evaluation_results.json.")
# Out:
# BLEU Score with smoothing: 8.643793438386789e-05
# [nltk_data] Downloading package wordnet to C:\Users\Gabriel
# [nltk_data]     prince\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Average METEOR Score: 0.0484401267339582
# Evaluation results written to evaluation_results.json.

# %%
import json
import zipfile

# Assume you have prediction_data and run_data dictionaries containing your prediction and run information

# Write prediction_data to prediction.json
with open("prediction.json", "w") as prediction_file:
    json.dump(output_data, prediction_file)

# Write run_data to run.json
with open("run.json", "w") as run_file:
    json.dump(run_data, run_file)

# Create a ZIP file
with zipfile.ZipFile("run.zip", "w") as zip_file:
    # Add prediction.json to the ZIP file
    zip_file.write("prediction.json", arcname="prediction.json")
    # Add run.json to the ZIP file
    zip_file.write("run.json", arcname="run.json")

print("run.zip created successfully.")

# %%
# Load test.json
with open('valid.json', 'r') as f:
    x_valid_data = json.load(f)

# Preprocess audio data for test samples
X_valid_encoder = []  # For encoder input
X_valid_decoder = []  # For decoder input
id = []  # To store test sample IDs

for sample in x_valid_data:
    audio_path = os.path.join('extracted_content/clips', sample['src'])
    spectrogram = preprocess_audio(audio_path, (128, 200))  # Assuming spectrogram shape is (128, 200)
    if spectrogram is not None:
        X_valid_encoder.append(spectrogram)
        X_valid_decoder.append(spectrogram)  # Decoder input same as encoder input
        id.append(sample['id'])

# Convert test data to NumPy arrays
X_valid_encoder_numpy = np.array(X_valid_encoder)
X_valid_decoder_numpy = np.array(X_valid_decoder)
# Out:
# C:\Users\Gabriel prince\anaconda3\Lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=160
#   warnings.warn(

# %%
perdict_valid = model.predict([X_valid_encoder_numpy,X_valid_decoder_numpy])
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step

# %%
# Decode token indices into words or pictogram terms
hyp_valid = []
for prediction in perdict_valid:
    decoded_prediction = [reverse_word_index.get(index, '') for index in np.argmax(prediction, axis=-1)]
    # Find the index of the first padding token (0)
    padding_index = next((i for i, x in enumerate(decoded_prediction) if x == ''), len(decoded_prediction))
    # Truncate the decoded prediction to remove padding tokens
    decoded_prediction = decoded_prediction[:padding_index]
    # Filter out empty strings and join the words/pictogram terms into a single string
    decoded_prediction_str = ' '.join(filter(None, decoded_prediction))
    # Capitalize the first letter of each word
    decoded_prediction_str = ' '.join(word.capitalize() for word in decoded_prediction_str.split())
    hyp_valid.append(decoded_prediction_str)

# %%
# Define a reverse mapping from indices to words or pictogram terms
reverse_word_index = {index: word for word, index in tokenizer.word_index.items()}

# Decode token indices into words or pictogram terms
hyp_valid = []
for prediction in perdict_valid:
    decoded_prediction = [reverse_word_index.get(index, '') for index in np.argmax(prediction, axis=-1)]
    # Filter out empty strings and join the words/pictogram terms into a single string
    decoded_prediction_str = ' '.join(filter(None, decoded_prediction))
    # Capitalize the first letter of each word
    decoded_prediction_str = ' '.join(word.capitalize() for word in decoded_prediction_str.split())
    hyp_valid.append(decoded_prediction_str)

# %%
hyp_valid[0]
# Out:
# '<oov> <oov> Ã©poque Parler Ils <oov> Le Maison Groupe Groupe But But Maison Lã Groupe Ils Maison Maison Me Oui Passã© 00 00 Un Un Passã© Maison 00 00 00 Oui Maison Maison Une Ãªtre Maison Maison Maison 00 00 00 Maison 00 00 00 00 Maison Maison Maison Maison Maison Me 00 Maison Me Me Maison Maison Maison Oui Maison Oui Oui Oui Oui Oui Oui Maison Alors Alors Oui Alors Alors Oui Oui Oui Que <oov> <oov> <oov> Que Ã©poque Ã©poque <oov> Alors Alors Alors Ã©poque Ã©poque Est <oov> <oov> <oov> Ã©poque <oov> <oov> <oov> <oov> <oov> <oov> <oov> Est Est <oov> <oov> <oov> <oov> Ã©poque <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov> Il Il <oov> <oov> <oov> <oov> <oov> <oov> <oov> <oov>'

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import SmoothingFunction, corpus_bleu

# Smooth function
smooth = SmoothingFunction().method4



# Assuming decoded_predictions is a list containing the decoded predictions generated by your model
# And hypotheses is a list containing the ground truth hypotheses

# Preprocess hypotheses to match the format expected by corpus_bleu
references = valid_target_sequences

# Preprocess decoded_predictions to match the format expected by corpus_bleu
decoded_predictions_tokenized =  [np.unique(hyp.split()) for hyp in hyp_valid]


# Calculate BLEU score with smoothing
bleu_score = corpus_bleu(references,decoded_predictions_tokenized, smoothing_function=smooth)

print("BLEU Score with smoothing:", bleu_score)
# Out:
# BLEU Score with smoothing: 8.643793438386789e-05

# %%
import nltk
nltk.download('wordnet')

from nltk.tokenize import word_tokenize
from nltk.translate.meteor_score import meteor_score

# Tokenize references
tokenized_references = [word_tokenize(ref) for ref in valid_target_sequences]

# Tokenize hypotheses
tokenized_hypotheses = [word_tokenize(hyp) for hyp in hyp_valid]

# Calculate METEOR score
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(tokenized_references, tokenized_hypotheses)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print("Average METEOR Score:", average_meteor_score)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Gabriel
# [nltk_data]     prince\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Average METEOR Score: 0.0484401267339582

# %%
len(references) , len(decoded_predictions_tokenized)
# Out:
# (1348, 1348)

# %%
model.save(r"D:\OneDrive\Desktop\IMAGECLEF\Model\speech_to_picto.keras")

# %%
from tensorflow.keras.models import load_model

# Load the model
summa = load_model(r"D:\OneDrive\Desktop\IMAGECLEF\Model\speech_to_picto.keras")
